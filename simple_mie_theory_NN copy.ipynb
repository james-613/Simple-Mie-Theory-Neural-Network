# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import PyMieScatt as ps
import pymiediff as pmd
import time
# Reproducibility — same "random" numbers every run
np.random.seed(42)
torch.manual_seed(42)

# %%
# Brown carbon at the center of our range
n = 1.6
k = 1.0
wavelength = 500   # nm
diameter = 800     # nm

m = complex(n, k)
theta, SL, SR, SU = ps.ScatteringFunction(
    m, wavelength, diameter,
    minAngle=0, maxAngle=180, angularResolution=1
)

print("theta shape:", theta.shape)
print("SU shape:", SU.shape)
print("First few SU values:", SU[:5])

plt.figure(figsize=(9, 5))
plt.plot(theta, SU)
plt.xlabel("Angle (degrees)")
plt.ylabel("Scattering intensity (SU)")
plt.title(f"Brown carbon scattering: d={diameter}nm, λ={wavelength}nm, m=1.6+1.0j")
plt.yscale('log')
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# theta shape: (181,)
# SU shape: (181,)
# First few SU values: [274.50568018 273.77890685 271.60879971 268.02578541 263.07987412]

# %%
N_SAMPLES = 1000


# inputs_saved = np.load('inputs_5d.npy')           # (N, 5)
# outputs_saved = np.load('outputs_5d.npy')         # (N, 1)

# Pre-allocate arrays
inputs = np.zeros((N_SAMPLES, 4))     # everything but angle
outputs = np.zeros((N_SAMPLES, 181))  # 181 angles per curve
derivatives = np.zeros((N_SAMPLES, 4, 181))

# The blueprint function: takes 5 normalized inputs, returns log scattering
def compute_log_scattering(n_norm, k_norm, wavelength_norm, diameter_norm, theta_norm):
    # Convert normalized to physical values
    wavelength = wavelength_norm * 100 + 450
    diameter   = diameter_norm * 300 + 600
    n          = n_norm * 0.36 + 1.5
    k          = k_norm * 0.32 + 0.68
    theta_rad  = theta_norm * torch.pi
    
    # pyMieDiff setup
    # pyMieDiff setup
    particle = pmd.Particle(
        r_layers=torch.stack([diameter / 2]),
        mat_layers=[n + 1j * k],     # tensor-based complex (preserves gradients)
        mat_env=1.00
    )

    k0 = 2 * torch.pi / wavelength
    
    scattering = particle.get_angular_scattering(k0=k0, theta=theta_rad)
    return torch.log10(scattering['i_unpol'])

# Fixed values for brown carbon
# n = 1.6
# k = 1.0
# m = complex(n, k)

print("Generating training data through physics")

for i in range(N_SAMPLES):
    # Sample random wavelength and diameter
    wavelength_norm = torch.tensor(np.random.uniform(0, 1), requires_grad=True) # 450 to 550
    diameter_norm = torch.tensor(np.random.uniform(0, 1), requires_grad=True) # 600 - 900
    n_norm = torch.tensor(np.random.uniform(0, 1), requires_grad = True) # 1.5 - 1.86
    k_norm = torch.tensor(np.random.uniform(0, 1), requires_grad = True) # 0.68 - 1.00
    m = complex(n, k)
    theta_norm      = torch.tensor(np.linspace(0, 1, 181)) # 0 to 1 maps to 0 to 180
    
    SU = compute_log_scattering(wavelength_norm, diameter_norm, n_norm, k_norm, theta_norm)

    jacobian_derivative = torch.autograd.functional.jacobian(
        compute_log_scattering,
        (n_norm, k_norm, wavelength_norm, diameter_norm, theta_norm),
        vectorize=True,
        create_graph=True
    )
    
    # Store inputs and outputs
    inputs[i] = [wavelength, diameter, n, k]
    outputs[i] = SU.detach().numpy()
    
    # Store derivatives
    derivatives[i, 0] = jacobian_derivative[2].detach().numpy()           # delta scattering/delta wavelength
    derivatives[i, 1] = jacobian_derivative[3].detach().numpy()           # delta scattering/delta diameter
    derivatives[i, 2] = jacobian_derivative[0].detach().numpy()           # delta scattering/delta n
    # Diameter gradient usually zero in pyMieDiff autograd — keep placeholder zeros
    derivatives[i, 3] = jacobian_derivative[1].detach().numpy()           # delta scattering/delta k
    # Theta derivative: place in column 4
    # derivatives[i, 4] = jacobian_derivative[4].diag().detach().numpy()    # delta scattering/delta theta (diagonal)
    
    if i % 100 == 0:
        print(f"  {i}/{N_SAMPLES} done")

print("\nDone!")
print("Inputs shape:", inputs.shape)
print("Outputs shape:", outputs.shape)
print("Derivatives shape:", derivatives.shape)

print("Derivative stats:")
for i, name in enumerate(['wavelength', 'diameter', 'n', 'k']):
    d = derivatives[:, i, :]
    print(f"  {name}: mean={d.mean():.4f}, std={d.std():.4f}, zeros={np.sum(d==0)}")
# Out:
# Generating training data through physics
#   0/1000 done
#   100/1000 done
#   200/1000 done
#   300/1000 done
#   400/1000 done
#   500/1000 done
#   600/1000 done
#   700/1000 done
#   800/1000 done
#   900/1000 done
#
# Done!
# Inputs shape: (1000, 4)
# Outputs shape: (1000, 181)
# Derivatives shape: (1000, 4, 181)
# Derivative stats:
#   wavelength: mean=-0.1468, std=0.2280, zeros=0
#   diameter: mean=0.2946, std=0.4686, zeros=0
#   n: mean=0.0539, std=0.0354, zeros=0
#   k: mean=0.1166, std=0.0643, zeros=0

# %% [markdown]
# took 4 minutes and 20 seconds for mie theory calculations for 10000 samples

# %%
plt.figure(figsize=(10, 6))

# Plot 5 random curves
indices = np.random.choice(N_SAMPLES, 5, replace=False)

# generate lables for each line
# for i in indices:
#     label = f"λ={inputs[i,0]:.10f}nm, d={inputs[i,1]:.10f}nm"
#     plt.plot(10 ** outputs[i], label=label)
plt.plot(10 ** outputs[0])

plt.xlabel("Angle (degrees)")
plt.ylabel("Scattering intensity (SU)")
plt.title("5 random training curves")
plt.yscale('log')
plt.legend(fontsize=9)
plt.grid(True, alpha=1.0)
plt.show()
# Out:
# C:\Users\james\AppData\Local\Temp\ipykernel_19340\2731552931.py:16: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(fontsize=9)

# %% [markdown]
# graphed 5 random training data points, just to see the shape of the results

# %%
# 1. Log-transform the outputs
# log_outputs = np.log10(outputs)   # base-10 log
# print(log_outputs)

# 2. Normalize the inputs to roughly [0, 1]
# wavelength: 450-550 → (wavelength - 450) / 100
# diameter:   600-900 → (diameter - 600) / 200
inputs_norm = np.zeros_like(inputs)
inputs_norm[:, 0] = (inputs[:, 0] - 450) / 100         # wavelength
inputs_norm[:, 1] = (inputs[:, 1] - 600) / 300        # diameter
inputs_norm[:, 2] = (inputs[:, 2] - 1.5) / (1.86-1.5)  # n
inputs_norm[:, 3] = (inputs[:, 3] - 0.68) / (1.00-0.68) # k

# 3. Train/test split — 80% train, 20% test
n_train = int(0.8 * N_SAMPLES)
x_train = inputs_norm[:n_train]
y_train = outputs[:n_train]
dy_train = torch.FloatTensor(derivatives[:n_train])

x_test  = inputs_norm[n_train:]
y_test  = outputs[n_train:]
dy_test  = torch.FloatTensor(derivatives[n_train:])

# Convert to PyTorch tensors
x_train = torch.FloatTensor(x_train)
y_train = torch.FloatTensor(y_train)
x_test  = torch.FloatTensor(x_test)
y_test  = torch.FloatTensor(y_test)

print("X_train shape:", x_train.shape)
print("y_train shape:", y_train.shape)
print("X_test shape:",  x_test.shape)
print("y_test shape:",  y_test.shape)
print()
print("Sample input (normalized):", x_train[0])
# Out:
# X_train shape: torch.Size([800, 4])
# y_train shape: torch.Size([800, 181])
# X_test shape: torch.Size([200, 4])
# y_test shape: torch.Size([200, 181])
#
# Sample input (normalized): tensor([0.5000, 0.6667, 0.2778, 1.0000])

# %% [markdown]
# Split the data into training and testing data, formatting the data so it's ready for training. Converting numpy arrays into Tensors.

# %%
model = nn.Sequential(
    nn.Linear(4, 128),       # input layer: 4 features to 128 neurons
    nn.GELU(),
    nn.Linear(128, 256),     # hidden layer: 32 -> 64
    nn.GELU(),
    nn.Linear(256, 512),
    nn.GELU(),
    nn.Linear(512, 256),
    nn.GELU(),
    nn.Linear(256, 181)    
)

print(model)

# Count parameters
total_params = sum(p.numel() for p in model.parameters())
print(f"\nTotal parameters: {total_params}")
# Out:
# Sequential(
#   (0): Linear(in_features=4, out_features=128, bias=True)
#   (1): GELU(approximate='none')
#   (2): Linear(in_features=128, out_features=256, bias=True)
#   (3): GELU(approximate='none')
#   (4): Linear(in_features=256, out_features=512, bias=True)
#   (5): GELU(approximate='none')
#   (6): Linear(in_features=512, out_features=256, bias=True)
#   (7): GELU(approximate='none')
#   (8): Linear(in_features=256, out_features=181, bias=True)
# )
#
# Total parameters: 343093

# %% [markdown]
# building NN layers, applying ReLu between each. Printing the model and counting the number of parameters.

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)
loss_fn = nn.MSELoss()

print("Optimizer:", optimizer)
print("Loss function:", loss_fn)
# Out:
# Optimizer: Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.0001
#     maximize: False
#     weight_decay: 0
# )
# Loss function: MSELoss()

# %%
from torch.func import vmap, jacrev

def single_forward(x):
    return model(x)  # x shape: (4,)

N_EPOCHS = 200
BATCH_SIZE = 32

train_losses = []
test_losses = []

n_train = x_train.shape[0]   # 800
n_batches = n_train // BATCH_SIZE  # 800 // 32 = 25

print(f"Training: {N_EPOCHS} epochs, {n_batches} batches per epoch\n")

import time

training_start = time.time()

for epoch in range(N_EPOCHS):
    # Shuffle training data each epoch
    perm = torch.randperm(n_train)# generates a random permutation of the numbers up to 800
    x_shuffled = x_train[perm] # shuffle the training data according to the permutation
    y_shuffled = y_train[perm] # shuffle the 'answers' for the training data
    dy_shuffled = dy_train[perm]
    # Train one epoch (one pass through the data, in mini-batches)
    epoch_loss = 0.0
    for i in range(n_batches):
        start = i * BATCH_SIZE # index work to see where batch starts
        end = start + BATCH_SIZE # index work to see where each batch ends while looping through the batches
        x_batch = x_shuffled[start:end].clone().requires_grad_(True) # diameters and wavelengths used in this batch
        y_batch = y_shuffled[start:end] # light scattered at each angle in this batch
        dy_batch = dy_shuffled[start:end]

        # Standard 5-step training pattern
        pred = model(x_batch) # predict
        loss_intensity = loss_fn(pred, y_batch)

        # jacrev gives d(output_181) / d(input_4) for a single sample → shape (181, 4)
        batched_jacobian = vmap(jacrev(single_forward))(x_batch)  # → (BATCH_SIZE, 181, 4)

        # Rearrange to (BATCH_SIZE, 4, 181) to match dy_batch
        nn_derivative = batched_jacobian.permute(0, 2, 1)  # → (BATCH_SIZE, 4, 181)
        
        # print(nn_derivative.shape)
        # print("First column")
        # print(nn_derivative[0])
        # print("Second column")
        # print(nn_derivative[1])
        # print("Third column")
        # print(nn_derivative[2])
        # print("Fourth column")
        # print(nn_derivative[3])
        
        # print(nn_derivative)
        # print(dy_batch.shape)

        loss_derivative = loss_fn(nn_derivative, dy_batch) # get the loss

        print(f"intensity: {loss_intensity.item():.6f}  derivative: {loss_derivative.item():.6f}")

        loss = loss_intensity + 0.1 * loss_derivative
        
        optimizer.zero_grad() # clears gradients from previous batches
        loss.backward() # back propagation to compute gradients for all weights
        optimizer.step() #updates all weights using the gradients
        
        epoch_loss += loss.item() # records the loss over the batches for graphing
    
    avg_train_loss = epoch_loss / n_batches # average across all 25 batches
    train_losses.append(avg_train_loss) # save avg loss for plotting
    
    # Evaluate on test set (no gradients needed)
    with torch.no_grad():
        test_pred = model(x_test) #predict on 200 test examples
        test_loss = loss_fn(test_pred, y_test).item() #compute MSE on test set

        loss_intensity = loss_fn(test_pred, y_test)

        # jacrev gives d(output_181) / d(input_4) for a single sample → shape (181, 4)
        batched_jacobian = vmap(jacrev(single_forward))(x_test)  # → (BATCH_SIZE, 181, 4)

        # Rearrange to (BATCH_SIZE, 4, 181) to match dy_batch
        test_nn_derivative = batched_jacobian.permute(0, 2, 1)  # → (BATCH_SIZE, 4, 181)
        loss_derivative = loss_fn(test_nn_derivative, dy_test)

        test_losses.append(test_loss) # save it
    
    if epoch % 20 == 0:
        print(f"Epoch {epoch:3d}  Train Loss: {avg_train_loss:.10f}  Test Loss: {test_loss:.10f}")

elapsed = time.time() - training_start
print(f"Total time: {elapsed:.2f}s")
print(f"Final loss: {train_losses[-1]:.6e}")
print("\nTraining complete!")
# Out:
# Training: 200 epochs, 25 batches per epoch
#
# intensity: 0.015910  derivative: 0.096089
# intensity: 0.018613  derivative: 0.096566
# intensity: 0.018258  derivative: 0.096119
# intensity: 0.020319  derivative: 0.090531
# intensity: 0.018636  derivative: 0.098580
# intensity: 0.018326  derivative: 0.081975
# intensity: 0.018430  derivative: 0.087213
# intensity: 0.015491  derivative: 0.097230
# intensity: 0.018397  derivative: 0.093969
# intensity: 0.020607  derivative: 0.100510
# intensity: 0.020543  derivative: 0.095594
# intensity: 0.020859  derivative: 0.093984
# intensity: 0.018763  derivative: 0.093586
# intensity: 0.016606  derivative: 0.100082
# intensity: 0.021099  derivative: 0.090836
# intensity: 0.020696  derivative: 0.098014
# intensity: 0.028061  derivative: 0.108680
# intensity: 0.015125  derivative: 0.096684
# intensity: 0.022326  derivative: 0.097443
# intensity: 0.023812  derivative: 0.105596
# intensity: 0.024639  derivative: 0.086715
# intensity: 0.018024  derivative: 0.099479
# intensity: 0.016241  derivative: 0.099122
# intensity: 0.013012  derivative: 0.086319
# intensity: 0.016792  derivative: 0.094784
# Epoch   0  Train Loss: 0.0287261866  Test Loss: 0.0184987970
# intensity: 0.018344  derivative: 0.098233
# intensity: 0.016358  derivative: 0.094870
# intensity: 0.016375  derivative: 0.104810
# intensity: 0.015982  derivative: 0.086770
# intensity: 0.021773  derivative: 0.096908
# intensity: 0.022125  derivative: 0.082983
# intensity: 0.021135  derivative: 0.086145
# intensity: 0.019403  derivative: 0.089183
# intensity: 0.022614  derivative: 0.088348
# intensity: 0.019126  derivative: 0.091831
# intensity: 0.015494  derivative: 0.081286
# intensity: 0.022532  derivative: 0.089690
# intensity: 0.020324  derivative: 0.099347
# intensity: 0.013803  derivative: 0.098947
# intensity: 0.024070  derivative: 0.094885
# intensity: 0.014632  derivative: 0.091416
# intensity: 0.024850  derivative: 0.092203
# intensity: 0.021325  derivative: 0.089818
# intensity: 0.024151  derivative: 0.091419
# intensity: 0.020546  derivative: 0.094299
# intensity: 0.018013  derivative: 0.090031
# intensity: 0.016614  derivative: 0.102159
# intensity: 0.017470  derivative: 0.087887
# intensity: 0.019396  derivative: 0.094850
# intensity: 0.018138  derivative: 0.095609
# intensity: 0.016133  derivative: 0.083870
# intensity: 0.017406  derivative: 0.090094
# intensity: 0.023310  derivative: 0.091389
# intensity: 0.021989  derivative: 0.090019
# intensity: 0.019131  derivative: 0.090695
# intensity: 0.017681  derivative: 0.095980
# intensity: 0.021897  derivative: 0.104915
# intensity: 0.024097  derivative: 0.093845
# intensity: 0.020503  derivative: 0.088211
# intensity: 0.023492  derivative: 0.085207
# intensity: 0.016457  derivative: 0.091429
# intensity: 0.023217  derivative: 0.096582
# intensity: 0.018799  derivative: 0.090721
# intensity: 0.019044  derivative: 0.097583
# intensity: 0.024293  derivative: 0.088380
# intensity: 0.017838  derivative: 0.089970
# intensity: 0.019342  derivative: 0.083629
# intensity: 0.018509  derivative: 0.083035
# intensity: 0.015454  derivative: 0.094055
# intensity: 0.017976  derivative: 0.083692
# intensity: 0.016449  derivative: 0.089950
# intensity: 0.016056  derivative: 0.089181
# intensity: 0.016517  derivative: 0.086339
# intensity: 0.021765  derivative: 0.091915
# intensity: 0.017398  derivative: 0.095638
# intensity: 0.021558  derivative: 0.090125
# intensity: 0.017511  derivative: 0.095527
# intensity: 0.012073  derivative: 0.082831
# intensity: 0.021626  derivative: 0.092741
# intensity: 0.021046  derivative: 0.089347
# intensity: 0.018139  derivative: 0.083918
# intensity: 0.021980  derivative: 0.090722
# intensity: 0.017667  derivative: 0.089059
# intensity: 0.019797  derivative: 0.087687
# intensity: 0.010650  derivative: 0.087325
# intensity: 0.015086  derivative: 0.094146
# intensity: 0.016295  derivative: 0.090754
# intensity: 0.020429  derivative: 0.094811
# intensity: 0.024927  derivative: 0.090407
# intensity: 0.015142  derivative: 0.089663
# intensity: 0.022192  derivative: 0.083998
# intensity: 0.020185  derivative: 0.083746
# intensity: 0.021357  derivative: 0.086766
# intensity: 0.016984  derivative: 0.089565
# intensity: 0.022119  derivative: 0.078169
# intensity: 0.023902  derivative: 0.079552
# intensity: 0.021974  derivative: 0.091736
# intensity: 0.020741  derivative: 0.082121
# intensity: 0.023224  derivative: 0.094467
# intensity: 0.022664  derivative: 0.086988
# intensity: 0.016356  derivative: 0.086344
# intensity: 0.018911  derivative: 0.086061
# intensity: 0.019619  derivative: 0.082229
# intensity: 0.015926  derivative: 0.084221
# intensity: 0.019062  derivative: 0.087469
# intensity: 0.023973  derivative: 0.074425
# intensity: 0.022901  derivative: 0.085548
# intensity: 0.018707  derivative: 0.078665
# intensity: 0.013441  derivative: 0.086043
# intensity: 0.021406  derivative: 0.096405
# intensity: 0.015672  derivative: 0.089395
# intensity: 0.017389  derivative: 0.076629
# intensity: 0.025316  derivative: 0.093741
# intensity: 0.025600  derivative: 0.091709
# intensity: 0.018106  derivative: 0.083571
# intensity: 0.022421  derivative: 0.098051
# intensity: 0.018564  derivative: 0.085273
# intensity: 0.013431  derivative: 0.089832
# intensity: 0.017912  derivative: 0.096197
# intensity: 0.016294  derivative: 0.084321
# intensity: 0.022035  derivative: 0.089498
# intensity: 0.021028  derivative: 0.086850
# intensity: 0.018234  derivative: 0.087075
# intensity: 0.021038  derivative: 0.082912
# intensity: 0.018126  derivative: 0.087902
# intensity: 0.018078  derivative: 0.093995
# intensity: 0.020995  derivative: 0.090443
# intensity: 0.018957  derivative: 0.080668
# intensity: 0.016483  derivative: 0.083842
# intensity: 0.022316  derivative: 0.093315
# intensity: 0.017820  derivative: 0.083999
# intensity: 0.019068  derivative: 0.090383
# intensity: 0.021908  derivative: 0.084439
# intensity: 0.017103  derivative: 0.086821
# intensity: 0.021193  derivative: 0.088692
# intensity: 0.015876  derivative: 0.084336
# intensity: 0.018116  derivative: 0.079962
# intensity: 0.016047  derivative: 0.090599
# intensity: 0.019169  derivative: 0.088634
# intensity: 0.022937  derivative: 0.088323
# intensity: 0.019119  derivative: 0.082927
# intensity: 0.020229  derivative: 0.085130
# intensity: 0.018184  derivative: 0.086201
# intensity: 0.018344  derivative: 0.083461
# intensity: 0.020313  derivative: 0.076267
# intensity: 0.023339  derivative: 0.076898
# intensity: 0.017328  derivative: 0.085680
# intensity: 0.017522  derivative: 0.077085
# intensity: 0.019208  derivative: 0.086005
# intensity: 0.020356  derivative: 0.083737
# intensity: 0.021535  derivative: 0.083744
# intensity: 0.025335  derivative: 0.077144
# intensity: 0.019159  derivative: 0.086609
# intensity: 0.019636  derivative: 0.089209
# intensity: 0.020126  derivative: 0.086867
# intensity: 0.016252  derivative: 0.079096
# intensity: 0.017390  derivative: 0.084267
# intensity: 0.017230  derivative: 0.088343
# intensity: 0.020113  derivative: 0.072419
# intensity: 0.025067  derivative: 0.089528
# intensity: 0.020403  derivative: 0.097694
# intensity: 0.018962  derivative: 0.079432
# intensity: 0.012739  derivative: 0.081814
# intensity: 0.020515  derivative: 0.095028
# intensity: 0.021326  derivative: 0.081595
# intensity: 0.023348  derivative: 0.089487
# intensity: 0.019806  derivative: 0.079845
# intensity: 0.017378  derivative: 0.084238
# intensity: 0.020811  derivative: 0.076035
# intensity: 0.019841  derivative: 0.091642
# intensity: 0.017169  derivative: 0.079474
# intensity: 0.014997  derivative: 0.077744
# intensity: 0.016856  derivative: 0.079585
# intensity: 0.024321  derivative: 0.075272
# intensity: 0.020933  derivative: 0.081840
# intensity: 0.016346  derivative: 0.080893
# intensity: 0.018941  derivative: 0.078754
# intensity: 0.019812  derivative: 0.086545
# intensity: 0.022133  derivative: 0.084209
# intensity: 0.019683  derivative: 0.081364
# intensity: 0.020162  derivative: 0.083906
# intensity: 0.021201  derivative: 0.089957
# intensity: 0.021970  derivative: 0.075720
# intensity: 0.018166  derivative: 0.092917
# intensity: 0.020492  derivative: 0.085762
# intensity: 0.015873  derivative: 0.071176
# intensity: 0.014867  derivative: 0.090693
# intensity: 0.021236  derivative: 0.073170
# intensity: 0.015595  derivative: 0.094728
# intensity: 0.022833  derivative: 0.083649
# intensity: 0.019221  derivative: 0.074362
# intensity: 0.018744  derivative: 0.083567
# intensity: 0.021440  derivative: 0.079648
# intensity: 0.017276  derivative: 0.081031
# intensity: 0.024120  derivative: 0.077717
# intensity: 0.013141  derivative: 0.084899
# intensity: 0.016720  derivative: 0.080937
# intensity: 0.016012  derivative: 0.073904
# intensity: 0.023510  derivative: 0.078955
# intensity: 0.019930  derivative: 0.080969
# intensity: 0.020263  derivative: 0.077961
# intensity: 0.014345  derivative: 0.082668
# intensity: 0.029700  derivative: 0.088291
# intensity: 0.018074  derivative: 0.093080
# intensity: 0.018680  derivative: 0.080979
# intensity: 0.014350  derivative: 0.075566
# intensity: 0.017093  derivative: 0.073806
# intensity: 0.020693  derivative: 0.076850
# intensity: 0.018277  derivative: 0.086942
# intensity: 0.019467  derivative: 0.073124
# intensity: 0.020978  derivative: 0.082941
# intensity: 0.016158  derivative: 0.079950
# intensity: 0.017499  derivative: 0.077120
# intensity: 0.022252  derivative: 0.074095
# intensity: 0.018378  derivative: 0.086823
# intensity: 0.019344  derivative: 0.077817
# intensity: 0.023282  derivative: 0.085846
# intensity: 0.019397  derivative: 0.074047
# intensity: 0.021926  derivative: 0.081717
# intensity: 0.020500  derivative: 0.081523
# intensity: 0.021586  derivative: 0.081478
# intensity: 0.019632  derivative: 0.075396
# intensity: 0.015404  derivative: 0.077988
# intensity: 0.015920  derivative: 0.076836
# intensity: 0.021186  derivative: 0.080628
# intensity: 0.018413  derivative: 0.077557
# intensity: 0.022453  derivative: 0.081768
# intensity: 0.019123  derivative: 0.072502
# intensity: 0.015248  derivative: 0.069369
# intensity: 0.019902  derivative: 0.080794
# intensity: 0.023244  derivative: 0.088423
# intensity: 0.015667  derivative: 0.078600
# intensity: 0.025133  derivative: 0.082301
# intensity: 0.015865  derivative: 0.074469
# intensity: 0.016740  derivative: 0.070836
# intensity: 0.016282  derivative: 0.086111
# intensity: 0.020904  derivative: 0.077298
# intensity: 0.022415  derivative: 0.073011
# intensity: 0.020872  derivative: 0.082754
# intensity: 0.021649  derivative: 0.083173
# intensity: 0.021077  derivative: 0.081198
# intensity: 0.016098  derivative: 0.084426
# intensity: 0.019249  derivative: 0.082284
# intensity: 0.016893  derivative: 0.073083
# intensity: 0.015015  derivative: 0.075995
# intensity: 0.016438  derivative: 0.078674
# intensity: 0.024834  derivative: 0.071007
# intensity: 0.022942  derivative: 0.076771
# intensity: 0.018465  derivative: 0.074586
# intensity: 0.015133  derivative: 0.077863
# intensity: 0.023534  derivative: 0.079215
# intensity: 0.025085  derivative: 0.074889
# intensity: 0.017203  derivative: 0.075492
# intensity: 0.018796  derivative: 0.076106
# intensity: 0.016863  derivative: 0.065749
# intensity: 0.018798  derivative: 0.078329
# intensity: 0.019390  derivative: 0.081732
# intensity: 0.014639  derivative: 0.074166
# intensity: 0.019706  derivative: 0.073637
# intensity: 0.022449  derivative: 0.075609
# intensity: 0.021684  derivative: 0.077409
# intensity: 0.016949  derivative: 0.076440
# intensity: 0.019188  derivative: 0.076916
# intensity: 0.023119  derivative: 0.076652
# intensity: 0.016744  derivative: 0.067378
# intensity: 0.014829  derivative: 0.078573
# intensity: 0.019761  derivative: 0.089666
# intensity: 0.020526  derivative: 0.065555
# intensity: 0.016250  derivative: 0.075641
# intensity: 0.017597  derivative: 0.078114
# intensity: 0.020924  derivative: 0.074675
# intensity: 0.017194  derivative: 0.081216
# intensity: 0.021037  derivative: 0.074803
# intensity: 0.018346  derivative: 0.082997
# intensity: 0.020011  derivative: 0.074923
# intensity: 0.021713  derivative: 0.078567
# intensity: 0.022799  derivative: 0.072754
# intensity: 0.021466  derivative: 0.074399
# intensity: 0.015192  derivative: 0.070880
# intensity: 0.018335  derivative: 0.088055
# intensity: 0.020952  derivative: 0.078307
# intensity: 0.012016  derivative: 0.073460
# intensity: 0.019197  derivative: 0.074948
# intensity: 0.022789  derivative: 0.070872
# intensity: 0.025615  derivative: 0.076244
# intensity: 0.013362  derivative: 0.071340
# intensity: 0.016772  derivative: 0.068385
# intensity: 0.015064  derivative: 0.071575
# intensity: 0.019889  derivative: 0.075801
# intensity: 0.021909  derivative: 0.061681
# intensity: 0.020384  derivative: 0.077462
# intensity: 0.018362  derivative: 0.066927
# intensity: 0.020502  derivative: 0.070975
# intensity: 0.017010  derivative: 0.069790
# intensity: 0.019279  derivative: 0.073420
# intensity: 0.021843  derivative: 0.075881
# intensity: 0.017496  derivative: 0.079790
# intensity: 0.018297  derivative: 0.071551
# intensity: 0.025345  derivative: 0.077768
# intensity: 0.020834  derivative: 0.077581
# intensity: 0.023795  derivative: 0.074439
# intensity: 0.018074  derivative: 0.079256
# intensity: 0.023887  derivative: 0.078691
# intensity: 0.019657  derivative: 0.065749
# intensity: 0.018180  derivative: 0.072573
# intensity: 0.024049  derivative: 0.076441
# intensity: 0.017744  derivative: 0.065599
# intensity: 0.018410  derivative: 0.074347
# intensity: 0.020612  derivative: 0.072111
# intensity: 0.026349  derivative: 0.061191
# intensity: 0.025795  derivative: 0.083585
# intensity: 0.016474  derivative: 0.077553
# intensity: 0.014487  derivative: 0.079383
# intensity: 0.021559  derivative: 0.074693
# intensity: 0.015459  derivative: 0.070723
# intensity: 0.015523  derivative: 0.070584
# intensity: 0.017998  derivative: 0.066457
# intensity: 0.014793  derivative: 0.071026
# intensity: 0.024144  derivative: 0.067871
# intensity: 0.016600  derivative: 0.074738
# intensity: 0.016954  derivative: 0.070759
# intensity: 0.016308  derivative: 0.071469
# intensity: 0.017604  derivative: 0.063230
# intensity: 0.029470  derivative: 0.071611
# intensity: 0.025383  derivative: 0.071353
# intensity: 0.019825  derivative: 0.071370
# intensity: 0.020060  derivative: 0.072737
# intensity: 0.015600  derivative: 0.069173
# intensity: 0.018112  derivative: 0.074571
# intensity: 0.018640  derivative: 0.061263
# intensity: 0.021445  derivative: 0.069149
# intensity: 0.017952  derivative: 0.074322
# intensity: 0.014295  derivative: 0.067391
# intensity: 0.021638  derivative: 0.073560
# intensity: 0.025965  derivative: 0.073542
# intensity: 0.018858  derivative: 0.065714
# intensity: 0.020249  derivative: 0.069989
# intensity: 0.017428  derivative: 0.063832
# intensity: 0.026947  derivative: 0.073411
# intensity: 0.018344  derivative: 0.070206
# intensity: 0.016131  derivative: 0.078764
# intensity: 0.017329  derivative: 0.066034
# intensity: 0.023765  derivative: 0.069717
# intensity: 0.017470  derivative: 0.071295
# intensity: 0.019880  derivative: 0.065653
# intensity: 0.016846  derivative: 0.066447
# intensity: 0.016023  derivative: 0.070120
# intensity: 0.014790  derivative: 0.066704
# intensity: 0.023653  derivative: 0.067737
# intensity: 0.020031  derivative: 0.068917
# intensity: 0.016935  derivative: 0.068892
# intensity: 0.017564  derivative: 0.073292
# intensity: 0.024085  derivative: 0.071029
# intensity: 0.017564  derivative: 0.069354
# intensity: 0.015204  derivative: 0.068792
# intensity: 0.019906  derivative: 0.074966
# intensity: 0.024829  derivative: 0.064251
# intensity: 0.021844  derivative: 0.064476
# intensity: 0.019779  derivative: 0.068254
# intensity: 0.018466  derivative: 0.067266
# intensity: 0.019230  derivative: 0.063323
# intensity: 0.021943  derivative: 0.061652
# intensity: 0.018323  derivative: 0.076007
# intensity: 0.014314  derivative: 0.062786
# intensity: 0.023884  derivative: 0.076139
# intensity: 0.019012  derivative: 0.063694
# intensity: 0.027482  derivative: 0.070244
# intensity: 0.014920  derivative: 0.065482
# intensity: 0.018210  derivative: 0.065211
# intensity: 0.015387  derivative: 0.061092
# intensity: 0.024537  derivative: 0.068886
# intensity: 0.016647  derivative: 0.065672
# intensity: 0.019839  derivative: 0.062486
# intensity: 0.014980  derivative: 0.058299
# intensity: 0.017793  derivative: 0.071831
# intensity: 0.014203  derivative: 0.064358
# intensity: 0.020006  derivative: 0.065778
# intensity: 0.022400  derivative: 0.066132
# intensity: 0.022250  derivative: 0.064489
# intensity: 0.018128  derivative: 0.069160
# intensity: 0.017897  derivative: 0.067282
# intensity: 0.025186  derivative: 0.064618
# intensity: 0.021500  derivative: 0.067263
# intensity: 0.020567  derivative: 0.060851
# intensity: 0.020337  derivative: 0.067584
# intensity: 0.017561  derivative: 0.064974
# intensity: 0.020805  derivative: 0.065087
# intensity: 0.016798  derivative: 0.065635
# intensity: 0.014034  derivative: 0.060398
# intensity: 0.022354  derivative: 0.068197
# intensity: 0.022334  derivative: 0.062486
# intensity: 0.024282  derivative: 0.058496
# intensity: 0.025461  derivative: 0.068901
# intensity: 0.015460  derivative: 0.064400
# intensity: 0.020173  derivative: 0.063704
# intensity: 0.013270  derivative: 0.065627
# intensity: 0.015450  derivative: 0.074730
# intensity: 0.021581  derivative: 0.060183
# intensity: 0.020379  derivative: 0.068346
# intensity: 0.013234  derivative: 0.056055
# intensity: 0.022893  derivative: 0.066158
# intensity: 0.024113  derivative: 0.071725
# intensity: 0.022330  derivative: 0.061714
# intensity: 0.019261  derivative: 0.063690
# intensity: 0.022974  derivative: 0.060343
# intensity: 0.017701  derivative: 0.061199
# intensity: 0.017265  derivative: 0.057424
# intensity: 0.018149  derivative: 0.062373
# intensity: 0.020041  derivative: 0.068803
# intensity: 0.016456  derivative: 0.067400
# intensity: 0.019280  derivative: 0.062976
# intensity: 0.020814  derivative: 0.057622
# intensity: 0.018300  derivative: 0.068089
# intensity: 0.021214  derivative: 0.066922
# intensity: 0.020375  derivative: 0.061003
# intensity: 0.022528  derivative: 0.058161
# intensity: 0.021561  derivative: 0.072569
# intensity: 0.014750  derivative: 0.063762
# intensity: 0.013859  derivative: 0.059168
# intensity: 0.016074  derivative: 0.063459
# intensity: 0.023334  derivative: 0.062848
# intensity: 0.018340  derivative: 0.061333
# intensity: 0.016816  derivative: 0.063214
# intensity: 0.024054  derivative: 0.059890
# intensity: 0.019115  derivative: 0.059882
# intensity: 0.019632  derivative: 0.061317
# intensity: 0.016837  derivative: 0.068579
# intensity: 0.018108  derivative: 0.062565
# intensity: 0.026987  derivative: 0.059366
# intensity: 0.020022  derivative: 0.065654
# intensity: 0.020687  derivative: 0.066783
# intensity: 0.022203  derivative: 0.057689
# intensity: 0.022078  derivative: 0.065751
# intensity: 0.018439  derivative: 0.065276
# intensity: 0.019288  derivative: 0.068353
# intensity: 0.018387  derivative: 0.057658
# intensity: 0.015220  derivative: 0.056326
# intensity: 0.013323  derivative: 0.061791
# intensity: 0.019213  derivative: 0.061347
# intensity: 0.021515  derivative: 0.059775
# intensity: 0.023484  derivative: 0.062394
# intensity: 0.015756  derivative: 0.066813
# intensity: 0.017401  derivative: 0.062630
# intensity: 0.022187  derivative: 0.059845
# intensity: 0.019632  derivative: 0.057571
# intensity: 0.017856  derivative: 0.055115
# intensity: 0.018569  derivative: 0.059668
# intensity: 0.021544  derivative: 0.054455
# intensity: 0.015445  derivative: 0.062161
# intensity: 0.017316  derivative: 0.060593
# intensity: 0.020024  derivative: 0.060907
# intensity: 0.022295  derivative: 0.060788
# intensity: 0.015639  derivative: 0.057250
# intensity: 0.020974  derivative: 0.067040
# intensity: 0.019416  derivative: 0.062401
# intensity: 0.024745  derivative: 0.058524
# intensity: 0.019969  derivative: 0.062430
# intensity: 0.021023  derivative: 0.065092
# intensity: 0.016235  derivative: 0.051272
# intensity: 0.017917  derivative: 0.054448
# intensity: 0.021131  derivative: 0.054536
# intensity: 0.016908  derivative: 0.065282
# intensity: 0.019611  derivative: 0.062027
# intensity: 0.014941  derivative: 0.067459
# intensity: 0.015086  derivative: 0.054273
# intensity: 0.012768  derivative: 0.057432
# intensity: 0.022911  derivative: 0.064057
# intensity: 0.014267  derivative: 0.056906
# intensity: 0.023966  derivative: 0.059191
# intensity: 0.020043  derivative: 0.067548
# intensity: 0.020898  derivative: 0.061380
# intensity: 0.018021  derivative: 0.057355
# intensity: 0.021685  derivative: 0.063605
# intensity: 0.021595  derivative: 0.053006
# intensity: 0.020791  derivative: 0.056788
# intensity: 0.018998  derivative: 0.055108
# intensity: 0.023758  derivative: 0.057123
# intensity: 0.021345  derivative: 0.055855
# intensity: 0.025301  derivative: 0.065317
# intensity: 0.023257  derivative: 0.061767
# intensity: 0.018509  derivative: 0.063470
# intensity: 0.015112  derivative: 0.058304
# intensity: 0.019368  derivative: 0.050687
# intensity: 0.023297  derivative: 0.061036
# intensity: 0.013782  derivative: 0.053752
# intensity: 0.017687  derivative: 0.063720
# intensity: 0.019610  derivative: 0.058899
# intensity: 0.017256  derivative: 0.058693
# intensity: 0.019812  derivative: 0.060968
# intensity: 0.020506  derivative: 0.063685
# intensity: 0.020247  derivative: 0.056834
# intensity: 0.011138  derivative: 0.060510
# intensity: 0.018528  derivative: 0.064022
# intensity: 0.018925  derivative: 0.058889
# intensity: 0.022306  derivative: 0.057751
# intensity: 0.020195  derivative: 0.058470
# intensity: 0.017679  derivative: 0.052187
# intensity: 0.023378  derivative: 0.060743
# intensity: 0.020670  derivative: 0.061573
# intensity: 0.014240  derivative: 0.056898
# intensity: 0.013074  derivative: 0.058265
# intensity: 0.024501  derivative: 0.061888
# intensity: 0.013730  derivative: 0.062461
# intensity: 0.023893  derivative: 0.066695
# intensity: 0.019218  derivative: 0.055158
# intensity: 0.021499  derivative: 0.056196
# intensity: 0.018298  derivative: 0.050766
# intensity: 0.020345  derivative: 0.052808
# intensity: 0.020778  derivative: 0.068678
# intensity: 0.019490  derivative: 0.068604
# intensity: 0.018656  derivative: 0.055422
# intensity: 0.020414  derivative: 0.057395
# intensity: 0.026404  derivative: 0.051872
# intensity: 0.018492  derivative: 0.066541
# intensity: 0.022247  derivative: 0.048220
# intensity: 0.017259  derivative: 0.053498
# intensity: 0.016645  derivative: 0.052491
# intensity: 0.018758  derivative: 0.062011
# intensity: 0.023161  derivative: 0.058051
# intensity: 0.019697  derivative: 0.055413
# intensity: 0.024609  derivative: 0.058783
# intensity: 0.022095  derivative: 0.055600
# intensity: 0.019189  derivative: 0.059492
# intensity: 0.012274  derivative: 0.055495
# intensity: 0.017969  derivative: 0.062717
# Epoch  20  Train Loss: 0.0255258039  Test Loss: 0.0184624437
# intensity: 0.018401  derivative: 0.058841
# intensity: 0.023923  derivative: 0.056351
# intensity: 0.017205  derivative: 0.056184
# intensity: 0.016592  derivative: 0.063505
# intensity: 0.021323  derivative: 0.063209
# intensity: 0.015502  derivative: 0.059546
# intensity: 0.016923  derivative: 0.051541
# intensity: 0.024298  derivative: 0.057356
# intensity: 0.023193  derivative: 0.061140
# intensity: 0.017202  derivative: 0.051062
# intensity: 0.018112  derivative: 0.056115
# intensity: 0.019528  derivative: 0.067222
# intensity: 0.015613  derivative: 0.051498
# intensity: 0.021676  derivative: 0.056205
# intensity: 0.019566  derivative: 0.060068
# intensity: 0.021811  derivative: 0.056598
# intensity: 0.020122  derivative: 0.050210
# intensity: 0.020287  derivative: 0.059752
# intensity: 0.020586  derivative: 0.056197
# intensity: 0.017610  derivative: 0.060220
# intensity: 0.018475  derivative: 0.055338
# intensity: 0.017862  derivative: 0.055673
# intensity: 0.017497  derivative: 0.061186
# intensity: 0.016120  derivative: 0.062412
# intensity: 0.023729  derivative: 0.056029
# intensity: 0.015050  derivative: 0.061266
# intensity: 0.018251  derivative: 0.059968
# intensity: 0.021532  derivative: 0.067344
# intensity: 0.014190  derivative: 0.055231
# intensity: 0.019900  derivative: 0.053686
# intensity: 0.021673  derivative: 0.056528
# intensity: 0.017878  derivative: 0.055362
# intensity: 0.018856  derivative: 0.058628
# intensity: 0.015940  derivative: 0.056041
# intensity: 0.018117  derivative: 0.057619
# intensity: 0.017029  derivative: 0.052899
# intensity: 0.019472  derivative: 0.065377
# intensity: 0.017816  derivative: 0.050237
# intensity: 0.020596  derivative: 0.062731
# intensity: 0.022194  derivative: 0.056865
# intensity: 0.020245  derivative: 0.054176
# intensity: 0.020127  derivative: 0.061466
# intensity: 0.023993  derivative: 0.058107
# intensity: 0.017759  derivative: 0.050213
# intensity: 0.020479  derivative: 0.061312
# intensity: 0.023450  derivative: 0.057286
# intensity: 0.020983  derivative: 0.059145
# intensity: 0.020670  derivative: 0.055647
# intensity: 0.016040  derivative: 0.056553
# intensity: 0.025060  derivative: 0.049123
# intensity: 0.024327  derivative: 0.061180
# intensity: 0.026816  derivative: 0.057665
# intensity: 0.020602  derivative: 0.062325
# intensity: 0.018741  derivative: 0.059687
# intensity: 0.014877  derivative: 0.054785
# intensity: 0.021510  derivative: 0.049174
# intensity: 0.017690  derivative: 0.055520
# intensity: 0.017431  derivative: 0.063219
# intensity: 0.021283  derivative: 0.056399
# intensity: 0.023929  derivative: 0.064925
# intensity: 0.018594  derivative: 0.053028
# intensity: 0.018784  derivative: 0.059079
# intensity: 0.022266  derivative: 0.057851
# intensity: 0.019946  derivative: 0.057396
# intensity: 0.016424  derivative: 0.053976
# intensity: 0.021107  derivative: 0.052310
# intensity: 0.022441  derivative: 0.064521
# intensity: 0.020679  derivative: 0.058182
# intensity: 0.022985  derivative: 0.050700
# intensity: 0.015489  derivative: 0.051481
# intensity: 0.013655  derivative: 0.054055
# intensity: 0.019105  derivative: 0.060865
# intensity: 0.016095  derivative: 0.054350
# intensity: 0.022965  derivative: 0.055991
# intensity: 0.013225  derivative: 0.056359
# intensity: 0.014081  derivative: 0.052612
# intensity: 0.014906  derivative: 0.065436
# intensity: 0.022290  derivative: 0.066843
# intensity: 0.022926  derivative: 0.055820
# intensity: 0.020659  derivative: 0.058188
# intensity: 0.013986  derivative: 0.054383
# intensity: 0.024436  derivative: 0.062062
# intensity: 0.019764  derivative: 0.063552
# intensity: 0.016715  derivative: 0.054629
# intensity: 0.019857  derivative: 0.057749
# intensity: 0.022172  derivative: 0.064510
# intensity: 0.020067  derivative: 0.053651
# intensity: 0.016636  derivative: 0.045087
# intensity: 0.020497  derivative: 0.051843
# intensity: 0.016672  derivative: 0.062586
# intensity: 0.017994  derivative: 0.054459
# intensity: 0.021805  derivative: 0.061020
# intensity: 0.019061  derivative: 0.055402
# intensity: 0.022055  derivative: 0.052974
# intensity: 0.015403  derivative: 0.050267
# intensity: 0.024174  derivative: 0.051363
# intensity: 0.014971  derivative: 0.061443
# intensity: 0.022908  derivative: 0.052014
# intensity: 0.018211  derivative: 0.053198
# intensity: 0.018208  derivative: 0.058437
# intensity: 0.024225  derivative: 0.060596
# intensity: 0.016487  derivative: 0.048319
# intensity: 0.014560  derivative: 0.055398
# intensity: 0.022213  derivative: 0.055709
# intensity: 0.015745  derivative: 0.061413
# intensity: 0.019488  derivative: 0.053487
# intensity: 0.022046  derivative: 0.063201
# intensity: 0.022987  derivative: 0.048661
# intensity: 0.017542  derivative: 0.054536
# intensity: 0.018759  derivative: 0.064238
# intensity: 0.021105  derivative: 0.051945
# intensity: 0.016464  derivative: 0.056800
# intensity: 0.022045  derivative: 0.057309
# intensity: 0.017526  derivative: 0.056892
# intensity: 0.018412  derivative: 0.058663
# intensity: 0.023737  derivative: 0.056506
# intensity: 0.020985  derivative: 0.061221
# intensity: 0.018313  derivative: 0.058887
# intensity: 0.017788  derivative: 0.063092
# intensity: 0.014846  derivative: 0.050592
# intensity: 0.020932  derivative: 0.059679
# intensity: 0.022663  derivative: 0.056305
# intensity: 0.025456  derivative: 0.055087
# intensity: 0.020598  derivative: 0.055115
# intensity: 0.016763  derivative: 0.054074
# intensity: 0.021193  derivative: 0.060748
# intensity: 0.022158  derivative: 0.060132
# intensity: 0.016856  derivative: 0.057500
# intensity: 0.019849  derivative: 0.050632
# intensity: 0.018277  derivative: 0.053091
# intensity: 0.016947  derivative: 0.053482
# intensity: 0.023090  derivative: 0.060066
# intensity: 0.016960  derivative: 0.056397
# intensity: 0.015562  derivative: 0.062890
# intensity: 0.021456  derivative: 0.064102
# intensity: 0.023002  derivative: 0.069719
# intensity: 0.015362  derivative: 0.056080
# intensity: 0.017098  derivative: 0.056426
# intensity: 0.020122  derivative: 0.053613
# intensity: 0.013683  derivative: 0.053179
# intensity: 0.013828  derivative: 0.062176
# intensity: 0.019108  derivative: 0.048344
# intensity: 0.013938  derivative: 0.060887
# intensity: 0.025487  derivative: 0.046991
# intensity: 0.020344  derivative: 0.050833
# intensity: 0.025681  derivative: 0.057035
# intensity: 0.019852  derivative: 0.050224
# intensity: 0.016857  derivative: 0.053403
# intensity: 0.020421  derivative: 0.056950
# intensity: 0.024594  derivative: 0.057302
# intensity: 0.015076  derivative: 0.053966
# intensity: 0.015791  derivative: 0.052163
# intensity: 0.020947  derivative: 0.061384
# intensity: 0.014057  derivative: 0.047816
# intensity: 0.024706  derivative: 0.068026
# intensity: 0.020048  derivative: 0.056194
# intensity: 0.019490  derivative: 0.053837
# intensity: 0.018744  derivative: 0.051138
# intensity: 0.022015  derivative: 0.059766
# intensity: 0.022242  derivative: 0.056776
# intensity: 0.017210  derivative: 0.055976
# intensity: 0.017065  derivative: 0.052202
# intensity: 0.021122  derivative: 0.056082
# intensity: 0.019744  derivative: 0.053891
# intensity: 0.022880  derivative: 0.051808
# intensity: 0.022747  derivative: 0.054636
# intensity: 0.018551  derivative: 0.064541
# intensity: 0.018139  derivative: 0.058219
# intensity: 0.020639  derivative: 0.049289
# intensity: 0.017400  derivative: 0.054754
# intensity: 0.014281  derivative: 0.059383
# intensity: 0.023611  derivative: 0.053101
# intensity: 0.022462  derivative: 0.068037
# intensity: 0.018882  derivative: 0.060893
# intensity: 0.018217  derivative: 0.055888
# intensity: 0.016248  derivative: 0.053328
# intensity: 0.019865  derivative: 0.059974
# intensity: 0.023453  derivative: 0.053179
# intensity: 0.015839  derivative: 0.056082
# intensity: 0.016083  derivative: 0.054340
# intensity: 0.016729  derivative: 0.061353
# intensity: 0.026169  derivative: 0.059747
# intensity: 0.021793  derivative: 0.057778
# intensity: 0.018022  derivative: 0.059228
# intensity: 0.018430  derivative: 0.056812
# intensity: 0.018390  derivative: 0.044370
# intensity: 0.020074  derivative: 0.057596
# intensity: 0.018668  derivative: 0.055295
# intensity: 0.015233  derivative: 0.049562
# intensity: 0.017404  derivative: 0.055786
# intensity: 0.020962  derivative: 0.059863
# intensity: 0.015422  derivative: 0.061965
# intensity: 0.016574  derivative: 0.058137
# intensity: 0.022059  derivative: 0.061223
# intensity: 0.018948  derivative: 0.064475
# intensity: 0.017916  derivative: 0.052368
# intensity: 0.025745  derivative: 0.059139
# intensity: 0.016445  derivative: 0.049625
# intensity: 0.024981  derivative: 0.057861
# intensity: 0.019452  derivative: 0.048892
# intensity: 0.024140  derivative: 0.047305
# intensity: 0.015682  derivative: 0.055533
# intensity: 0.023489  derivative: 0.058604
# intensity: 0.023120  derivative: 0.053927
# intensity: 0.017788  derivative: 0.057450
# intensity: 0.014778  derivative: 0.051503
# intensity: 0.016118  derivative: 0.049342
# intensity: 0.016985  derivative: 0.059458
# intensity: 0.020840  derivative: 0.056021
# intensity: 0.015531  derivative: 0.053605
# intensity: 0.020926  derivative: 0.058345
# intensity: 0.022011  derivative: 0.051066
# intensity: 0.018720  derivative: 0.052869
# intensity: 0.017638  derivative: 0.050025
# intensity: 0.014523  derivative: 0.053577
# intensity: 0.019196  derivative: 0.058971
# intensity: 0.024533  derivative: 0.052812
# intensity: 0.021606  derivative: 0.059689
# intensity: 0.019849  derivative: 0.054348
# intensity: 0.019071  derivative: 0.062240
# intensity: 0.019945  derivative: 0.060370
# intensity: 0.015221  derivative: 0.062894
# intensity: 0.021368  derivative: 0.052019
# intensity: 0.023523  derivative: 0.064593
# intensity: 0.019370  derivative: 0.069792
# intensity: 0.020191  derivative: 0.053675
# intensity: 0.017418  derivative: 0.057672
# intensity: 0.015252  derivative: 0.061131
# intensity: 0.021127  derivative: 0.050772
# intensity: 0.019688  derivative: 0.058987
# intensity: 0.020118  derivative: 0.053251
# intensity: 0.016711  derivative: 0.052842
# intensity: 0.020356  derivative: 0.053734
# intensity: 0.023887  derivative: 0.053919
# intensity: 0.016531  derivative: 0.059583
# intensity: 0.018827  derivative: 0.063887
# intensity: 0.020234  derivative: 0.047948
# intensity: 0.017667  derivative: 0.053502
# intensity: 0.029118  derivative: 0.059757
# intensity: 0.017004  derivative: 0.052855
# intensity: 0.017527  derivative: 0.050972
# intensity: 0.019767  derivative: 0.062384
# intensity: 0.017902  derivative: 0.058576
# intensity: 0.020446  derivative: 0.057421
# intensity: 0.019721  derivative: 0.059097
# intensity: 0.016276  derivative: 0.059694
# intensity: 0.023389  derivative: 0.056526
# intensity: 0.015862  derivative: 0.053104
# intensity: 0.020165  derivative: 0.054568
# intensity: 0.023979  derivative: 0.059693
# intensity: 0.019727  derivative: 0.054549
# intensity: 0.020184  derivative: 0.051808
# intensity: 0.013739  derivative: 0.054676
# intensity: 0.019614  derivative: 0.057959
# intensity: 0.022273  derivative: 0.057852
# intensity: 0.017432  derivative: 0.064435
# intensity: 0.012684  derivative: 0.056936
# intensity: 0.027766  derivative: 0.062005
# intensity: 0.015462  derivative: 0.052530
# intensity: 0.015439  derivative: 0.057842
# intensity: 0.025343  derivative: 0.053304
# intensity: 0.024224  derivative: 0.054200
# intensity: 0.019749  derivative: 0.059244
# intensity: 0.020561  derivative: 0.061866
# intensity: 0.022318  derivative: 0.064475
# intensity: 0.017009  derivative: 0.047483
# intensity: 0.015608  derivative: 0.058585
# intensity: 0.019481  derivative: 0.057753
# intensity: 0.022122  derivative: 0.056201
# intensity: 0.025707  derivative: 0.058539
# intensity: 0.018440  derivative: 0.050432
# intensity: 0.017385  derivative: 0.059973
# intensity: 0.016703  derivative: 0.052776
# intensity: 0.024017  derivative: 0.051280
# intensity: 0.022425  derivative: 0.048188
# intensity: 0.018253  derivative: 0.051812
# intensity: 0.019076  derivative: 0.056916
# intensity: 0.021402  derivative: 0.059657
# intensity: 0.019384  derivative: 0.056266
# intensity: 0.022173  derivative: 0.059397
# intensity: 0.022347  derivative: 0.052474
# intensity: 0.015104  derivative: 0.052735
# intensity: 0.013984  derivative: 0.055324
# intensity: 0.017704  derivative: 0.053239
# intensity: 0.019194  derivative: 0.059101
# intensity: 0.015170  derivative: 0.056284
# intensity: 0.020816  derivative: 0.049828
# intensity: 0.018866  derivative: 0.057590
# intensity: 0.023157  derivative: 0.058311
# intensity: 0.015304  derivative: 0.050212
# intensity: 0.016877  derivative: 0.058170
# intensity: 0.022674  derivative: 0.063806
# intensity: 0.019944  derivative: 0.053405
# intensity: 0.017206  derivative: 0.057355
# intensity: 0.022945  derivative: 0.055385
# intensity: 0.023895  derivative: 0.053629
# intensity: 0.017836  derivative: 0.058234
# intensity: 0.017911  derivative: 0.050424
# intensity: 0.022326  derivative: 0.062661
# intensity: 0.017367  derivative: 0.061092
# intensity: 0.017778  derivative: 0.048912
# intensity: 0.021186  derivative: 0.058247
# intensity: 0.016597  derivative: 0.058074
# intensity: 0.024853  derivative: 0.045420
# intensity: 0.018590  derivative: 0.053724
# intensity: 0.014399  derivative: 0.062974
# intensity: 0.010907  derivative: 0.053055
# intensity: 0.020343  derivative: 0.057988
# intensity: 0.016048  derivative: 0.062016
# intensity: 0.014822  derivative: 0.060461
# intensity: 0.018426  derivative: 0.052876
# intensity: 0.019581  derivative: 0.057019
# intensity: 0.026479  derivative: 0.050142
# intensity: 0.017744  derivative: 0.063909
# intensity: 0.020849  derivative: 0.060817
# intensity: 0.020804  derivative: 0.058429
# intensity: 0.019717  derivative: 0.051896
# intensity: 0.025174  derivative: 0.058323
# intensity: 0.016820  derivative: 0.052472
# intensity: 0.019676  derivative: 0.049148
# intensity: 0.019485  derivative: 0.051567
# intensity: 0.016442  derivative: 0.054891
# intensity: 0.020190  derivative: 0.059366
# intensity: 0.021647  derivative: 0.055280
# intensity: 0.021796  derivative: 0.065534
# intensity: 0.014041  derivative: 0.054050
# intensity: 0.018826  derivative: 0.055138
# intensity: 0.018954  derivative: 0.057246
# intensity: 0.019831  derivative: 0.059168
# intensity: 0.019240  derivative: 0.054071
# intensity: 0.022927  derivative: 0.052087
# intensity: 0.017247  derivative: 0.060264
# intensity: 0.016869  derivative: 0.056097
# intensity: 0.019809  derivative: 0.054160
# intensity: 0.024183  derivative: 0.058023
# intensity: 0.020780  derivative: 0.053331
# intensity: 0.020846  derivative: 0.051005
# intensity: 0.017402  derivative: 0.049116
# intensity: 0.019759  derivative: 0.051556
# intensity: 0.015484  derivative: 0.056417
# intensity: 0.020886  derivative: 0.052640
# intensity: 0.020970  derivative: 0.054723
# intensity: 0.020110  derivative: 0.060703
# intensity: 0.019390  derivative: 0.065766
# intensity: 0.018550  derivative: 0.066415
# intensity: 0.022106  derivative: 0.056742
# intensity: 0.019927  derivative: 0.059294
# intensity: 0.022055  derivative: 0.053904
# intensity: 0.024663  derivative: 0.056691
# intensity: 0.011623  derivative: 0.053421
# intensity: 0.019909  derivative: 0.064049
# intensity: 0.016464  derivative: 0.052656
# intensity: 0.026761  derivative: 0.056198
# intensity: 0.014914  derivative: 0.051395
# intensity: 0.023845  derivative: 0.067166
# intensity: 0.024907  derivative: 0.053131
# intensity: 0.014234  derivative: 0.062885
# intensity: 0.022737  derivative: 0.051267
# intensity: 0.021909  derivative: 0.049369
# intensity: 0.020310  derivative: 0.054584
# intensity: 0.014000  derivative: 0.054967
# intensity: 0.023270  derivative: 0.058935
# intensity: 0.020674  derivative: 0.051268
# intensity: 0.018473  derivative: 0.056716
# intensity: 0.013352  derivative: 0.059979
# intensity: 0.019599  derivative: 0.047712
# intensity: 0.017012  derivative: 0.052893
# intensity: 0.019332  derivative: 0.055357
# intensity: 0.018001  derivative: 0.049804
# intensity: 0.019251  derivative: 0.056721
# intensity: 0.020641  derivative: 0.059460
# intensity: 0.020319  derivative: 0.063747
# intensity: 0.024382  derivative: 0.054357
# intensity: 0.017464  derivative: 0.063714
# intensity: 0.015807  derivative: 0.052647
# intensity: 0.017251  derivative: 0.056665
# intensity: 0.022371  derivative: 0.053509
# intensity: 0.023589  derivative: 0.051543
# intensity: 0.016912  derivative: 0.052474
# intensity: 0.021335  derivative: 0.054875
# intensity: 0.013806  derivative: 0.059143
# intensity: 0.018020  derivative: 0.060575
# intensity: 0.021765  derivative: 0.063553
# intensity: 0.018885  derivative: 0.058472
# intensity: 0.022202  derivative: 0.054159
# intensity: 0.018208  derivative: 0.061344
# intensity: 0.018350  derivative: 0.047266
# intensity: 0.018430  derivative: 0.040259
# intensity: 0.016831  derivative: 0.059886
# intensity: 0.020581  derivative: 0.056869
# intensity: 0.016107  derivative: 0.050368
# intensity: 0.019511  derivative: 0.056259
# intensity: 0.014997  derivative: 0.056082
# intensity: 0.025796  derivative: 0.063137
# intensity: 0.019771  derivative: 0.057765
# intensity: 0.016987  derivative: 0.053710
# intensity: 0.021291  derivative: 0.065366
# intensity: 0.017866  derivative: 0.049380
# intensity: 0.019232  derivative: 0.063563
# intensity: 0.023317  derivative: 0.054438
# intensity: 0.016730  derivative: 0.056475
# intensity: 0.016958  derivative: 0.055536
# intensity: 0.023896  derivative: 0.063600
# intensity: 0.018703  derivative: 0.053659
# intensity: 0.021853  derivative: 0.054555
# intensity: 0.017692  derivative: 0.052103
# intensity: 0.018621  derivative: 0.055368
# intensity: 0.021158  derivative: 0.047999
# intensity: 0.017147  derivative: 0.056486
# intensity: 0.013850  derivative: 0.049603
# intensity: 0.023636  derivative: 0.055601
# intensity: 0.026517  derivative: 0.063377
# intensity: 0.016933  derivative: 0.054560
# intensity: 0.015497  derivative: 0.049138
# intensity: 0.023245  derivative: 0.065633
# intensity: 0.017126  derivative: 0.051866
# intensity: 0.023779  derivative: 0.059473
# intensity: 0.021516  derivative: 0.054982
# intensity: 0.019139  derivative: 0.055539
# intensity: 0.020867  derivative: 0.063733
# intensity: 0.016171  derivative: 0.062828
# intensity: 0.022820  derivative: 0.061563
# intensity: 0.017098  derivative: 0.055743
# intensity: 0.020164  derivative: 0.060823
# intensity: 0.025902  derivative: 0.041218
# intensity: 0.017814  derivative: 0.057361
# intensity: 0.016960  derivative: 0.052616
# intensity: 0.015080  derivative: 0.065972
# intensity: 0.015034  derivative: 0.052183
# intensity: 0.017470  derivative: 0.056426
# intensity: 0.016150  derivative: 0.059794
# intensity: 0.022465  derivative: 0.052252
# intensity: 0.019812  derivative: 0.052476
# intensity: 0.019017  derivative: 0.054262
# intensity: 0.017665  derivative: 0.063066
# intensity: 0.013622  derivative: 0.062761
# intensity: 0.014443  derivative: 0.054265
# intensity: 0.025559  derivative: 0.057635
# intensity: 0.017886  derivative: 0.050217
# intensity: 0.020736  derivative: 0.056131
# intensity: 0.018895  derivative: 0.055060
# intensity: 0.024591  derivative: 0.059768
# intensity: 0.021138  derivative: 0.049455
# intensity: 0.020620  derivative: 0.055403
# intensity: 0.021744  derivative: 0.056629
# intensity: 0.018301  derivative: 0.058995
# intensity: 0.024302  derivative: 0.046426
# intensity: 0.024893  derivative: 0.061526
# intensity: 0.019392  derivative: 0.055542
# intensity: 0.018804  derivative: 0.053522
# intensity: 0.014167  derivative: 0.053773
# intensity: 0.019373  derivative: 0.049561
# intensity: 0.017199  derivative: 0.045951
# intensity: 0.016931  derivative: 0.054161
# intensity: 0.016859  derivative: 0.060425
# intensity: 0.019079  derivative: 0.060178
# intensity: 0.018894  derivative: 0.052890
# intensity: 0.016460  derivative: 0.059008
# intensity: 0.017604  derivative: 0.051838
# intensity: 0.021313  derivative: 0.061977
# intensity: 0.024931  derivative: 0.048489
# intensity: 0.018149  derivative: 0.057727
# intensity: 0.016840  derivative: 0.059252
# intensity: 0.017973  derivative: 0.057564
# intensity: 0.028464  derivative: 0.052358
# intensity: 0.022762  derivative: 0.063310
# intensity: 0.019958  derivative: 0.056812
# intensity: 0.016110  derivative: 0.053214
# intensity: 0.015563  derivative: 0.056726
# intensity: 0.022119  derivative: 0.058796
# intensity: 0.024096  derivative: 0.064579
# intensity: 0.019486  derivative: 0.060213
# intensity: 0.020950  derivative: 0.056641
# intensity: 0.022054  derivative: 0.052753
# intensity: 0.014986  derivative: 0.052385
# intensity: 0.021709  derivative: 0.058818
# intensity: 0.016366  derivative: 0.054216
# intensity: 0.020596  derivative: 0.056346
# intensity: 0.017702  derivative: 0.054590
# intensity: 0.020685  derivative: 0.051327
# intensity: 0.018934  derivative: 0.050874
# intensity: 0.023456  derivative: 0.052400
# intensity: 0.017401  derivative: 0.060677
# intensity: 0.016332  derivative: 0.061630
# intensity: 0.017233  derivative: 0.063094
# intensity: 0.018342  derivative: 0.053917
# intensity: 0.021462  derivative: 0.059898
# intensity: 0.016834  derivative: 0.055988
# intensity: 0.022465  derivative: 0.059106
# intensity: 0.017633  derivative: 0.057449
# intensity: 0.020535  derivative: 0.050220
# intensity: 0.020107  derivative: 0.059976
# intensity: 0.017091  derivative: 0.065478
# intensity: 0.021503  derivative: 0.054511
# intensity: 0.023459  derivative: 0.051914
# intensity: 0.021083  derivative: 0.054652
# intensity: 0.018827  derivative: 0.046674
# intensity: 0.016128  derivative: 0.053509
# intensity: 0.017383  derivative: 0.058632
# intensity: 0.019129  derivative: 0.053011
# Epoch  40  Train Loss: 0.0248914261  Test Loss: 0.0190175399
# intensity: 0.017248  derivative: 0.064890
# intensity: 0.019049  derivative: 0.047023
# intensity: 0.024531  derivative: 0.045963
# intensity: 0.021549  derivative: 0.051969
# intensity: 0.017600  derivative: 0.061768
# intensity: 0.016014  derivative: 0.061813
# intensity: 0.019717  derivative: 0.056725
# intensity: 0.024215  derivative: 0.063933
# intensity: 0.014626  derivative: 0.053990
# intensity: 0.025133  derivative: 0.056043
# intensity: 0.015896  derivative: 0.055435
# intensity: 0.023620  derivative: 0.058834
# intensity: 0.022201  derivative: 0.053692
# intensity: 0.022394  derivative: 0.048743
# intensity: 0.015613  derivative: 0.057985
# intensity: 0.016361  derivative: 0.052409
# intensity: 0.017827  derivative: 0.059104
# intensity: 0.015462  derivative: 0.055555
# intensity: 0.020840  derivative: 0.055110
# intensity: 0.021929  derivative: 0.060067
# intensity: 0.018459  derivative: 0.052567
# intensity: 0.018147  derivative: 0.057076
# intensity: 0.020332  derivative: 0.059692
# intensity: 0.021276  derivative: 0.053691
# intensity: 0.018862  derivative: 0.054188
# intensity: 0.016160  derivative: 0.056756
# intensity: 0.023149  derivative: 0.058915
# intensity: 0.024246  derivative: 0.054780
# intensity: 0.014335  derivative: 0.054408
# intensity: 0.017246  derivative: 0.059854
# intensity: 0.018520  derivative: 0.050308
# intensity: 0.023820  derivative: 0.059630
# intensity: 0.028723  derivative: 0.058529
# intensity: 0.021887  derivative: 0.048328
# intensity: 0.021421  derivative: 0.054014
# intensity: 0.020763  derivative: 0.061646
# intensity: 0.013610  derivative: 0.043557
# intensity: 0.016783  derivative: 0.055086
# intensity: 0.017184  derivative: 0.064347
# intensity: 0.020776  derivative: 0.055837
# intensity: 0.015733  derivative: 0.059742
# intensity: 0.017794  derivative: 0.052257
# intensity: 0.018236  derivative: 0.059780
# intensity: 0.022157  derivative: 0.052807
# intensity: 0.017191  derivative: 0.065801
# intensity: 0.018241  derivative: 0.054068
# intensity: 0.015246  derivative: 0.051368
# intensity: 0.018307  derivative: 0.054789
# intensity: 0.018955  derivative: 0.065696
# intensity: 0.021453  derivative: 0.045420
# intensity: 0.018320  derivative: 0.060388
# intensity: 0.020063  derivative: 0.049317
# intensity: 0.024530  derivative: 0.048912
# intensity: 0.018908  derivative: 0.064669
# intensity: 0.020012  derivative: 0.054838
# intensity: 0.026771  derivative: 0.051863
# intensity: 0.020331  derivative: 0.054697
# intensity: 0.020282  derivative: 0.058431
# intensity: 0.019184  derivative: 0.052639
# intensity: 0.020075  derivative: 0.059307
# intensity: 0.019484  derivative: 0.046690
# intensity: 0.020649  derivative: 0.055842
# intensity: 0.019119  derivative: 0.056212
# intensity: 0.018807  derivative: 0.051468
# intensity: 0.019086  derivative: 0.059835
# intensity: 0.018768  derivative: 0.054344
# intensity: 0.018690  derivative: 0.052289
# intensity: 0.015096  derivative: 0.055340
# intensity: 0.021907  derivative: 0.068799
# intensity: 0.017979  derivative: 0.058557
# intensity: 0.022065  derivative: 0.055465
# intensity: 0.016730  derivative: 0.061330
# intensity: 0.016864  derivative: 0.050347
# intensity: 0.017574  derivative: 0.049650
# intensity: 0.015297  derivative: 0.066815
# intensity: 0.017323  derivative: 0.049770
# intensity: 0.017104  derivative: 0.059492
# intensity: 0.016363  derivative: 0.054585
# intensity: 0.011961  derivative: 0.058216
# intensity: 0.023935  derivative: 0.058219
# intensity: 0.014799  derivative: 0.055178
# intensity: 0.014410  derivative: 0.056499
# intensity: 0.020354  derivative: 0.050906
# intensity: 0.017834  derivative: 0.062030
# intensity: 0.020029  derivative: 0.056816
# intensity: 0.019256  derivative: 0.055433
# intensity: 0.018377  derivative: 0.046782
# intensity: 0.019561  derivative: 0.059501
# intensity: 0.027110  derivative: 0.050786
# intensity: 0.022786  derivative: 0.064436
# intensity: 0.023452  derivative: 0.058062
# intensity: 0.023647  derivative: 0.045662
# intensity: 0.015821  derivative: 0.056282
# intensity: 0.017512  derivative: 0.058551
# intensity: 0.026135  derivative: 0.057173
# intensity: 0.017887  derivative: 0.053085
# intensity: 0.020663  derivative: 0.058781
# intensity: 0.018992  derivative: 0.056288
# intensity: 0.021945  derivative: 0.052836
# intensity: 0.019365  derivative: 0.061884
# intensity: 0.016757  derivative: 0.052647
# intensity: 0.016575  derivative: 0.067226
# intensity: 0.018132  derivative: 0.053536
# intensity: 0.014566  derivative: 0.058742
# intensity: 0.021544  derivative: 0.056362
# intensity: 0.021377  derivative: 0.061633
# intensity: 0.021010  derivative: 0.059037
# intensity: 0.022089  derivative: 0.051439
# intensity: 0.020326  derivative: 0.050484
# intensity: 0.017719  derivative: 0.050655
# intensity: 0.015659  derivative: 0.054909
# intensity: 0.022119  derivative: 0.052693
# ...
# intensity: 0.020071  derivative: 0.043186
# intensity: 0.017106  derivative: 0.049335
# intensity: 0.020980  derivative: 0.049305
# intensity: 0.020246  derivative: 0.067060
# intensity: 0.019125  derivative: 0.050902
# intensity: 0.018371  derivative: 0.053368
# intensity: 0.015981  derivative: 0.064580
# intensity: 0.017986  derivative: 0.053173
# intensity: 0.024561  derivative: 0.053940
# intensity: 0.020262  derivative: 0.065604
# intensity: 0.018340  derivative: 0.068178
# intensity: 0.017756  derivative: 0.054965
# intensity: 0.019414  derivative: 0.059115
# intensity: 0.019674  derivative: 0.053968
# intensity: 0.022843  derivative: 0.051870
# intensity: 0.014644  derivative: 0.054079
# intensity: 0.020676  derivative: 0.048966
# intensity: 0.023332  derivative: 0.046727
# intensity: 0.014249  derivative: 0.056392
# intensity: 0.016759  derivative: 0.051749
# intensity: 0.018971  derivative: 0.052732
# intensity: 0.009539  derivative: 0.048258
# intensity: 0.019539  derivative: 0.053610
# intensity: 0.019484  derivative: 0.043768
# intensity: 0.018715  derivative: 0.051701
# intensity: 0.019462  derivative: 0.049849
# intensity: 0.021582  derivative: 0.052861
# intensity: 0.022414  derivative: 0.048516
# intensity: 0.024849  derivative: 0.072894
# intensity: 0.023412  derivative: 0.057229
# intensity: 0.020172  derivative: 0.057262
# intensity: 0.021612  derivative: 0.051840
# intensity: 0.020755  derivative: 0.053177
# intensity: 0.018657  derivative: 0.049683
# intensity: 0.017280  derivative: 0.046117
# intensity: 0.022062  derivative: 0.051108
# intensity: 0.016325  derivative: 0.060549
# intensity: 0.019833  derivative: 0.049147
# intensity: 0.022146  derivative: 0.050550
# intensity: 0.018706  derivative: 0.049212
# intensity: 0.019512  derivative: 0.065760
# intensity: 0.021954  derivative: 0.050276
# intensity: 0.021268  derivative: 0.055788
# intensity: 0.015504  derivative: 0.057637
# intensity: 0.019105  derivative: 0.051876
# intensity: 0.013083  derivative: 0.062437
# intensity: 0.015756  derivative: 0.053344
# intensity: 0.019767  derivative: 0.057740
# intensity: 0.015856  derivative: 0.058213
# intensity: 0.019677  derivative: 0.056055
# intensity: 0.016157  derivative: 0.052724
# intensity: 0.018255  derivative: 0.053385
# intensity: 0.022247  derivative: 0.050262
# intensity: 0.023579  derivative: 0.059435
# intensity: 0.022466  derivative: 0.058059
# intensity: 0.019233  derivative: 0.063110
# intensity: 0.019197  derivative: 0.059772
# intensity: 0.023872  derivative: 0.050321
# intensity: 0.021045  derivative: 0.058051
# intensity: 0.021867  derivative: 0.051006
# intensity: 0.019062  derivative: 0.048557
# intensity: 0.020328  derivative: 0.049845
# intensity: 0.014065  derivative: 0.061289
# intensity: 0.016745  derivative: 0.054166
# intensity: 0.014882  derivative: 0.049858
# intensity: 0.016859  derivative: 0.056976
# intensity: 0.018744  derivative: 0.047732
# intensity: 0.018895  derivative: 0.053018
# intensity: 0.018422  derivative: 0.050799
# intensity: 0.014220  derivative: 0.053726
# intensity: 0.019552  derivative: 0.066211
# intensity: 0.020938  derivative: 0.051025
# intensity: 0.017653  derivative: 0.055998
# intensity: 0.018306  derivative: 0.057860
# intensity: 0.023108  derivative: 0.056244
# intensity: 0.018074  derivative: 0.049743
# intensity: 0.023352  derivative: 0.059029
# intensity: 0.021255  derivative: 0.050309
# intensity: 0.017790  derivative: 0.048236
# intensity: 0.018912  derivative: 0.046322
# intensity: 0.019643  derivative: 0.051958
# intensity: 0.020708  derivative: 0.057792
# intensity: 0.017912  derivative: 0.059287
# intensity: 0.018157  derivative: 0.049014
# intensity: 0.016582  derivative: 0.049708
# intensity: 0.013759  derivative: 0.051512
# intensity: 0.018590  derivative: 0.056550
# intensity: 0.021258  derivative: 0.050634
# intensity: 0.018576  derivative: 0.051863
# intensity: 0.022532  derivative: 0.062328
# intensity: 0.024736  derivative: 0.053313
# intensity: 0.021016  derivative: 0.056113
# intensity: 0.019143  derivative: 0.046784
# intensity: 0.018805  derivative: 0.059052
# intensity: 0.020106  derivative: 0.055353
# intensity: 0.021240  derivative: 0.059303
# intensity: 0.017149  derivative: 0.056423
# intensity: 0.017410  derivative: 0.053535
# intensity: 0.019736  derivative: 0.056900
# intensity: 0.016524  derivative: 0.046011
# intensity: 0.022619  derivative: 0.054993
# intensity: 0.018864  derivative: 0.063973
# intensity: 0.021164  derivative: 0.059209
# intensity: 0.017170  derivative: 0.053353
# intensity: 0.022373  derivative: 0.065993
# intensity: 0.023285  derivative: 0.058542
# intensity: 0.024224  derivative: 0.049458
# intensity: 0.020915  derivative: 0.052342
# intensity: 0.021113  derivative: 0.046520
# intensity: 0.019714  derivative: 0.057222
# intensity: 0.018470  derivative: 0.049716
# intensity: 0.019445  derivative: 0.056193
# intensity: 0.019630  derivative: 0.051154
# intensity: 0.019453  derivative: 0.050938
# intensity: 0.018411  derivative: 0.049739
# intensity: 0.026933  derivative: 0.053966
# intensity: 0.014051  derivative: 0.049636
# intensity: 0.021623  derivative: 0.058637
# intensity: 0.016411  derivative: 0.052218
# intensity: 0.017705  derivative: 0.054961
# intensity: 0.017691  derivative: 0.052851
# intensity: 0.014057  derivative: 0.054069
# intensity: 0.019047  derivative: 0.057544
# intensity: 0.019818  derivative: 0.056287
# intensity: 0.015718  derivative: 0.052478
# intensity: 0.016309  derivative: 0.054939
# intensity: 0.019099  derivative: 0.057284
# intensity: 0.017721  derivative: 0.066711
# intensity: 0.018390  derivative: 0.050794
# intensity: 0.022031  derivative: 0.052812
# intensity: 0.017052  derivative: 0.067284
# intensity: 0.018561  derivative: 0.059716
# intensity: 0.020637  derivative: 0.055655
# intensity: 0.020147  derivative: 0.057711
# intensity: 0.018693  derivative: 0.056094
# intensity: 0.021697  derivative: 0.051896
# intensity: 0.018052  derivative: 0.053661
# intensity: 0.020002  derivative: 0.059780
# intensity: 0.017761  derivative: 0.056369
# intensity: 0.019848  derivative: 0.050666
# intensity: 0.018524  derivative: 0.062414
# intensity: 0.020281  derivative: 0.060383
# intensity: 0.019584  derivative: 0.050996
# intensity: 0.020358  derivative: 0.048735
# intensity: 0.016997  derivative: 0.048478
# intensity: 0.019442  derivative: 0.048696
# intensity: 0.017317  derivative: 0.052330
# intensity: 0.019069  derivative: 0.051376
# intensity: 0.018925  derivative: 0.057760
# intensity: 0.018561  derivative: 0.052628
# intensity: 0.017246  derivative: 0.048761
# intensity: 0.017574  derivative: 0.061612
# intensity: 0.018207  derivative: 0.047340
# intensity: 0.021773  derivative: 0.047998
# intensity: 0.016657  derivative: 0.052169
# intensity: 0.018959  derivative: 0.054549
# intensity: 0.018713  derivative: 0.053347
# intensity: 0.017556  derivative: 0.055030
# intensity: 0.016523  derivative: 0.054259
# intensity: 0.018590  derivative: 0.058262
# intensity: 0.018854  derivative: 0.053556
# intensity: 0.021986  derivative: 0.061525
# intensity: 0.015024  derivative: 0.054778
# intensity: 0.021943  derivative: 0.054374
# intensity: 0.019645  derivative: 0.056239
# intensity: 0.014107  derivative: 0.054907
# intensity: 0.018149  derivative: 0.046161
# intensity: 0.014466  derivative: 0.053760
# intensity: 0.019515  derivative: 0.058856
# intensity: 0.023288  derivative: 0.055640
# intensity: 0.024962  derivative: 0.054665
# intensity: 0.022013  derivative: 0.060601
# intensity: 0.022535  derivative: 0.057716
# intensity: 0.017984  derivative: 0.050711
# intensity: 0.018666  derivative: 0.054207
# intensity: 0.018363  derivative: 0.057221
# intensity: 0.021105  derivative: 0.051769
# intensity: 0.020888  derivative: 0.051943
# intensity: 0.020044  derivative: 0.045314
# intensity: 0.022276  derivative: 0.048666
# intensity: 0.018275  derivative: 0.044173
# intensity: 0.022704  derivative: 0.055536
# intensity: 0.021657  derivative: 0.051394
# intensity: 0.019446  derivative: 0.061276
# intensity: 0.016033  derivative: 0.051249
# intensity: 0.020984  derivative: 0.057378
# intensity: 0.017596  derivative: 0.055315
# intensity: 0.020838  derivative: 0.058094
# intensity: 0.017044  derivative: 0.048683
# intensity: 0.021164  derivative: 0.063523
# intensity: 0.017818  derivative: 0.055586
# intensity: 0.019362  derivative: 0.052453
# intensity: 0.025962  derivative: 0.053134
# intensity: 0.019431  derivative: 0.058885
# intensity: 0.017238  derivative: 0.057729
# intensity: 0.015016  derivative: 0.053599
# intensity: 0.018333  derivative: 0.054031
# intensity: 0.015963  derivative: 0.056155
# intensity: 0.017652  derivative: 0.053190
# intensity: 0.021077  derivative: 0.054978
# intensity: 0.023117  derivative: 0.062268
# intensity: 0.018631  derivative: 0.057053
# intensity: 0.017925  derivative: 0.052785
# intensity: 0.020767  derivative: 0.044763
# intensity: 0.018547  derivative: 0.052194
# intensity: 0.014758  derivative: 0.052655
# intensity: 0.022361  derivative: 0.061413
# intensity: 0.022949  derivative: 0.058411
# intensity: 0.017634  derivative: 0.054618
# intensity: 0.028059  derivative: 0.054331
# intensity: 0.014308  derivative: 0.047991
# intensity: 0.023049  derivative: 0.058075
# intensity: 0.020179  derivative: 0.055041
# intensity: 0.020452  derivative: 0.047322
# intensity: 0.024412  derivative: 0.055331
# intensity: 0.019272  derivative: 0.052590
# intensity: 0.020659  derivative: 0.044258
# intensity: 0.018381  derivative: 0.055767
# intensity: 0.017924  derivative: 0.050229
# intensity: 0.021637  derivative: 0.050807
# intensity: 0.020588  derivative: 0.068455
# intensity: 0.015817  derivative: 0.055689
# intensity: 0.023083  derivative: 0.066557
# intensity: 0.019733  derivative: 0.060260
# intensity: 0.016978  derivative: 0.047628
# intensity: 0.016789  derivative: 0.054944
# intensity: 0.020514  derivative: 0.046323
# intensity: 0.016362  derivative: 0.054360
# intensity: 0.016593  derivative: 0.056520
# intensity: 0.014775  derivative: 0.052492
# intensity: 0.014164  derivative: 0.055581
# intensity: 0.019663  derivative: 0.059108
# intensity: 0.023493  derivative: 0.050282
# intensity: 0.017473  derivative: 0.051599
# intensity: 0.019413  derivative: 0.055347
# intensity: 0.015907  derivative: 0.057131
# intensity: 0.018927  derivative: 0.056562
# intensity: 0.021813  derivative: 0.058252
# intensity: 0.022214  derivative: 0.056110
# intensity: 0.027234  derivative: 0.053833
# intensity: 0.022702  derivative: 0.054194
# intensity: 0.013565  derivative: 0.053381
# intensity: 0.023202  derivative: 0.053317
# intensity: 0.020235  derivative: 0.049228
# intensity: 0.016680  derivative: 0.045518
# intensity: 0.025908  derivative: 0.049633
# intensity: 0.020900  derivative: 0.063195
# intensity: 0.017959  derivative: 0.051646
# intensity: 0.013706  derivative: 0.050459
# intensity: 0.019916  derivative: 0.050869
# intensity: 0.017693  derivative: 0.053446
# intensity: 0.018722  derivative: 0.056533
# intensity: 0.018579  derivative: 0.063181
# intensity: 0.018761  derivative: 0.060228
# intensity: 0.020918  derivative: 0.056072
# intensity: 0.020270  derivative: 0.057156
# intensity: 0.021907  derivative: 0.051884
# intensity: 0.017993  derivative: 0.049253
# intensity: 0.018494  derivative: 0.048926
# intensity: 0.020831  derivative: 0.056585
# intensity: 0.017610  derivative: 0.054520
# intensity: 0.021762  derivative: 0.052008
# intensity: 0.019563  derivative: 0.058018
# intensity: 0.020270  derivative: 0.061612
# intensity: 0.016674  derivative: 0.054812
# intensity: 0.024012  derivative: 0.046747
# intensity: 0.018349  derivative: 0.056419
# intensity: 0.021955  derivative: 0.044173
# intensity: 0.019595  derivative: 0.057988
# intensity: 0.021074  derivative: 0.043175
# intensity: 0.018534  derivative: 0.058475
# intensity: 0.020536  derivative: 0.055398
# intensity: 0.017952  derivative: 0.065575
# intensity: 0.016509  derivative: 0.057276
# intensity: 0.018871  derivative: 0.053494
# intensity: 0.014486  derivative: 0.059999
# intensity: 0.015264  derivative: 0.051402
# intensity: 0.018218  derivative: 0.056191
# intensity: 0.019787  derivative: 0.053956
# intensity: 0.021712  derivative: 0.044136
# intensity: 0.012402  derivative: 0.048108
# intensity: 0.020059  derivative: 0.051444
# intensity: 0.019191  derivative: 0.058027
# intensity: 0.022870  derivative: 0.053474
# intensity: 0.020686  derivative: 0.054700
# intensity: 0.026235  derivative: 0.056914
# intensity: 0.020540  derivative: 0.053795
# intensity: 0.022254  derivative: 0.054650
# intensity: 0.018456  derivative: 0.059433
# intensity: 0.020251  derivative: 0.056275
# intensity: 0.020492  derivative: 0.054820
# intensity: 0.015831  derivative: 0.053539
# intensity: 0.020614  derivative: 0.057884
# intensity: 0.017453  derivative: 0.051444
# intensity: 0.015972  derivative: 0.044841
# intensity: 0.018169  derivative: 0.045753
# intensity: 0.020337  derivative: 0.057816
# intensity: 0.021194  derivative: 0.058998
# intensity: 0.014249  derivative: 0.047525
# intensity: 0.020089  derivative: 0.056000
# intensity: 0.017793  derivative: 0.064622
# intensity: 0.020424  derivative: 0.057414
# intensity: 0.019199  derivative: 0.057933
# intensity: 0.021451  derivative: 0.061969
# intensity: 0.019748  derivative: 0.052353
# intensity: 0.022665  derivative: 0.051322
# intensity: 0.019788  derivative: 0.050855
# intensity: 0.020243  derivative: 0.053500
# intensity: 0.016165  derivative: 0.046409
# intensity: 0.018395  derivative: 0.063440
# intensity: 0.018227  derivative: 0.059641
# intensity: 0.020054  derivative: 0.053471
# intensity: 0.023368  derivative: 0.042041
# intensity: 0.022430  derivative: 0.069408
# intensity: 0.018560  derivative: 0.051362
# intensity: 0.019823  derivative: 0.058611
# intensity: 0.015366  derivative: 0.051505
# intensity: 0.023174  derivative: 0.064691
# intensity: 0.020663  derivative: 0.046142
# intensity: 0.024757  derivative: 0.055869
# intensity: 0.015442  derivative: 0.054629
# intensity: 0.014106  derivative: 0.054307
# intensity: 0.019470  derivative: 0.056714
# intensity: 0.020040  derivative: 0.049006
# intensity: 0.018107  derivative: 0.050660
# intensity: 0.016155  derivative: 0.055806
# intensity: 0.019173  derivative: 0.062088
# intensity: 0.015640  derivative: 0.058653
# intensity: 0.019749  derivative: 0.048841
# intensity: 0.019425  derivative: 0.056187
# intensity: 0.021007  derivative: 0.061011
# intensity: 0.019484  derivative: 0.061331
# intensity: 0.016126  derivative: 0.045316
# intensity: 0.025829  derivative: 0.051109
# intensity: 0.022531  derivative: 0.050924
# intensity: 0.020284  derivative: 0.054358
# intensity: 0.018468  derivative: 0.054077
# intensity: 0.021706  derivative: 0.059706
# intensity: 0.019295  derivative: 0.054638
# intensity: 0.016062  derivative: 0.049162
# intensity: 0.019754  derivative: 0.047078
# intensity: 0.020747  derivative: 0.046462
# intensity: 0.015255  derivative: 0.055220
# intensity: 0.014201  derivative: 0.056583
# intensity: 0.020547  derivative: 0.052362
# intensity: 0.020124  derivative: 0.051599
# intensity: 0.019873  derivative: 0.063173
# intensity: 0.020613  derivative: 0.050380
# intensity: 0.019481  derivative: 0.061372
# intensity: 0.012005  derivative: 0.060478
# intensity: 0.023797  derivative: 0.057974
# intensity: 0.018564  derivative: 0.052143
# intensity: 0.015323  derivative: 0.054680
# intensity: 0.019004  derivative: 0.053055
# intensity: 0.021923  derivative: 0.049796
# intensity: 0.021826  derivative: 0.049130
# intensity: 0.016156  derivative: 0.050613
# intensity: 0.016933  derivative: 0.051913
# intensity: 0.018277  derivative: 0.044255
# intensity: 0.014074  derivative: 0.055349
# intensity: 0.022943  derivative: 0.050989
# intensity: 0.022822  derivative: 0.062827
# intensity: 0.020609  derivative: 0.061821
# intensity: 0.015360  derivative: 0.055135
# intensity: 0.019267  derivative: 0.062890
# intensity: 0.020799  derivative: 0.060188
# intensity: 0.022585  derivative: 0.065023
# intensity: 0.015060  derivative: 0.052817
# intensity: 0.021706  derivative: 0.057217
# intensity: 0.017278  derivative: 0.059302
# intensity: 0.018216  derivative: 0.053771
# intensity: 0.024413  derivative: 0.050543
# intensity: 0.020350  derivative: 0.057313
# intensity: 0.013621  derivative: 0.054833
# intensity: 0.025777  derivative: 0.050054
# intensity: 0.016007  derivative: 0.046784
# intensity: 0.019095  derivative: 0.055125
# intensity: 0.019232  derivative: 0.053044
# intensity: 0.017949  derivative: 0.050946
# Total time: 220.24s
# Final loss: 2.473790e-02
#
# Training complete!

# %% [markdown]
# Training the model. Randomizing the sequence of the training set. Split the set into a training and testing set. Also making sure loss is decreasing over time, ensuring we are approaching a minimum in the cost. Training took 10.7 seconds

# %%
plt.figure(figsize=(10, 5))
plt.plot(train_losses, label='Train loss')
plt.plot(test_losses, label='Test loss')
plt.xlabel("Epoch")
plt.ylabel("MSE Loss")
plt.title("Loss over training vs Loss over testing")
plt.yscale('log')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
with torch.no_grad():
    test_pred = model(x_test)

# Plot 4 random test cases
plt.figure(figsize=(11, 7))
indices = np.random.choice(len(x_test), 1, replace=False)

print(y_test[indices[0]])
print(test_pred[indices[0]])

# Use different colors for each pair so they're visually distinguishable
colors = ['blue', 'orange', 'green', 'red']

for idx, color in zip(indices, colors):

    # Get the actual physical values (un-normalize)
    norm_w = x_test[idx, 0].item()
    norm_d = x_test[idx, 1].item()
    real_w = norm_w * 100 + 450
    real_d = norm_d * 300 + 600
    
    # Convert log10 back to real brightness values
    true_curve = y_test[idx].numpy() ** 10 # take the log output brightness values and turn them back to their original values
    pred_curve = test_pred[idx].numpy() ** 10 # take the prediction values and turn them back to their original values
    
    # Solid line = truth (PyMieScatt), Dashed line = NN prediction
    plt.plot(true_curve, '-',  color=color, linewidth=2, alpha=0.8,
             label=f"Truth: λ={real_w:.10f}nm, d={real_d:.10f}nm")
    plt.plot(pred_curve, '--', color=color, linewidth=2, alpha=0.8,
             label=f"NN pred (test #{idx})")

plt.xlabel("Angle (degrees)")
plt.ylabel("Scattering intensity (SU)")
plt.title("PyMieScatt truth (solid) vs NN prediction (dashed)")
plt.yscale('log')
plt.legend(fontsize=8, ncol=2)
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# tensor([ 2.2663e+00,  2.2653e+00,  2.2625e+00,  2.2577e+00,  2.2510e+00,
#          2.2423e+00,  2.2318e+00,  2.2192e+00,  2.2047e+00,  2.1881e+00,
#          2.1696e+00,  2.1489e+00,  2.1262e+00,  2.1013e+00,  2.0743e+00,
#          2.0450e+00,  2.0135e+00,  1.9796e+00,  1.9433e+00,  1.9046e+00,
#          1.8633e+00,  1.8193e+00,  1.7726e+00,  1.7231e+00,  1.6706e+00,
#          1.6150e+00,  1.5562e+00,  1.4940e+00,  1.4284e+00,  1.3592e+00,
#          1.2862e+00,  1.2093e+00,  1.1285e+00,  1.0438e+00,  9.5553e-01,
#          8.6398e-01,  7.7002e-01,  6.7505e-01,  5.8126e-01,  4.9179e-01,
#          4.1073e-01,  3.4266e-01,  2.9160e-01,  2.5971e-01,  2.4639e-01,
#          2.4856e-01,  2.6180e-01,  2.8166e-01,  3.0440e-01,  3.2730e-01,
#          3.4853e-01,  3.6698e-01,  3.8202e-01,  3.9337e-01,  4.0093e-01,
#          4.0478e-01,  4.0504e-01,  4.0193e-01,  3.9567e-01,  3.8653e-01,
#          3.7480e-01,  3.6077e-01,  3.4476e-01,  3.2710e-01,  3.0814e-01,
#          2.8822e-01,  2.6771e-01,  2.4694e-01,  2.2626e-01,  2.0598e-01,
#          1.8637e-01,  1.6766e-01,  1.5002e-01,  1.3355e-01,  1.1830e-01,
#          1.0424e-01,  9.1282e-02,  7.9302e-02,  6.8135e-02,  5.7593e-02,
#          4.7485e-02,  3.7623e-02,  2.7839e-02,  1.7985e-02,  7.9499e-03,
#         -2.3441e-03, -1.2934e-02, -2.3816e-02, -3.4946e-02, -4.6239e-02,
#         -5.7573e-02, -6.8793e-02, -7.9716e-02, -9.0139e-02, -9.9848e-02,
#         -1.0863e-01, -1.1627e-01, -1.2261e-01, -1.2749e-01, -1.3082e-01,
#         -1.3256e-01, -1.3270e-01, -1.3133e-01, -1.2856e-01, -1.2456e-01,
#         -1.1951e-01, -1.1365e-01, -1.0719e-01, -1.0038e-01, -9.3434e-02,
#         -8.6572e-02, -7.9989e-02, -7.3858e-02, -6.8332e-02, -6.3540e-02,
#         -5.9590e-02, -5.6565e-02, -5.4531e-02, -5.3531e-02, -5.3594e-02,
#         -5.4727e-02, -5.6926e-02, -6.0169e-02, -6.4420e-02, -6.9632e-02,
#         -7.5740e-02, -8.2671e-02, -9.0337e-02, -9.8639e-02, -1.0747e-01,
#         -1.1670e-01, -1.2620e-01, -1.3584e-01, -1.4547e-01, -1.5494e-01,
#         -1.6410e-01, -1.7279e-01, -1.8087e-01, -1.8820e-01, -1.9467e-01,
#         -2.0015e-01, -2.0455e-01, -2.0782e-01, -2.0990e-01, -2.1076e-01,
#         -2.1042e-01, -2.0890e-01, -2.0624e-01, -2.0250e-01, -1.9777e-01,
#         -1.9214e-01, -1.8570e-01, -1.7856e-01, -1.7082e-01, -1.6259e-01,
#         -1.5397e-01, -1.4505e-01, -1.3593e-01, -1.2670e-01, -1.1744e-01,
#         -1.0821e-01, -9.9090e-02, -9.0137e-02, -8.1408e-02, -7.2952e-02,
#         -6.4814e-02, -5.7034e-02, -4.9651e-02, -4.2695e-02, -3.6196e-02,
#         -3.0181e-02, -2.4672e-02, -1.9690e-02, -1.5253e-02, -1.1377e-02,
#         -8.0751e-03, -5.3584e-03, -3.2361e-03, -1.7151e-03, -8.0057e-04,
#         -4.9539e-04])
# tensor([ 2.3270e+00,  2.3263e+00,  2.3246e+00,  2.3170e+00,  2.3109e+00,
#          2.3020e+00,  2.2907e+00,  2.2791e+00,  2.2620e+00,  2.2434e+00,
#          2.2221e+00,  2.2003e+00,  2.1734e+00,  2.1446e+00,  2.1174e+00,
#          2.0863e+00,  2.0511e+00,  2.0161e+00,  1.9730e+00,  1.9321e+00,
#          1.8844e+00,  1.8365e+00,  1.7846e+00,  1.7270e+00,  1.6703e+00,
#          1.6019e+00,  1.5334e+00,  1.4633e+00,  1.3895e+00,  1.3126e+00,
#          1.2294e+00,  1.1432e+00,  1.0558e+00,  9.7248e-01,  8.8929e-01,
#          8.1297e-01,  7.4699e-01,  6.8620e-01,  6.2743e-01,  5.8261e-01,
#          5.3964e-01,  5.0797e-01,  4.8572e-01,  4.6358e-01,  4.5118e-01,
#          4.4410e-01,  4.4109e-01,  4.3670e-01,  4.3335e-01,  4.3126e-01,
#          4.3387e-01,  4.2873e-01,  4.3066e-01,  4.2412e-01,  4.1719e-01,
#          4.0608e-01,  4.0052e-01,  3.9214e-01,  3.8339e-01,  3.6632e-01,
#          3.5417e-01,  3.4198e-01,  3.2814e-01,  3.1602e-01,  3.0110e-01,
#          2.8773e-01,  2.7306e-01,  2.5797e-01,  2.4538e-01,  2.2947e-01,
#          2.1792e-01,  2.0235e-01,  1.9373e-01,  1.8037e-01,  1.6964e-01,
#          1.5637e-01,  1.4754e-01,  1.3329e-01,  1.2727e-01,  1.1301e-01,
#          1.1196e-01,  9.8125e-02,  8.7042e-02,  8.3952e-02,  7.7169e-02,
#          6.6413e-02,  6.2179e-02,  4.9687e-02,  4.4541e-02,  3.8999e-02,
#          2.9531e-02,  2.6563e-02,  1.8480e-02,  1.1885e-02,  8.3138e-03,
#          5.9100e-03, -5.7669e-04, -4.5201e-03, -9.6892e-03, -1.2904e-02,
#         -1.8817e-02, -2.0697e-02, -2.6871e-02, -2.8241e-02, -3.1727e-02,
#         -3.7511e-02, -3.5420e-02, -3.8334e-02, -4.1931e-02, -4.3132e-02,
#         -4.1796e-02, -4.6151e-02, -4.4301e-02, -4.6345e-02, -4.7861e-02,
#         -4.8517e-02, -4.6082e-02, -4.6165e-02, -4.5066e-02, -5.1052e-02,
#         -4.8906e-02, -5.1014e-02, -5.0722e-02, -4.8345e-02, -4.8706e-02,
#         -4.9274e-02, -5.1074e-02, -5.3308e-02, -5.3914e-02, -5.1330e-02,
#         -5.3667e-02, -5.1677e-02, -5.5351e-02, -5.7351e-02, -5.6473e-02,
#         -5.6914e-02, -5.9051e-02, -6.2783e-02, -5.8170e-02, -6.4757e-02,
#         -6.4073e-02, -6.2691e-02, -6.3942e-02, -6.1200e-02, -6.4031e-02,
#         -6.4182e-02, -6.6472e-02, -6.6460e-02, -6.6582e-02, -6.9422e-02,
#         -7.2631e-02, -6.8692e-02, -7.2381e-02, -7.2619e-02, -7.1699e-02,
#         -7.4807e-02, -7.3128e-02, -7.1116e-02, -7.8121e-02, -7.4601e-02,
#         -8.0517e-02, -7.6487e-02, -7.7498e-02, -7.9747e-02, -8.2807e-02,
#         -7.9553e-02, -8.0115e-02, -8.2224e-02, -8.3591e-02, -8.3570e-02,
#         -8.4948e-02, -8.7244e-02, -8.2885e-02, -8.6550e-02, -8.5493e-02,
#         -8.5966e-02, -8.6114e-02, -8.4942e-02, -8.8630e-02, -8.6984e-02,
#         -8.6816e-02])

# %% [markdown]
# Todo: Still have to try out the tan h compression function between layers. Try to

# %%
def predict_scattering(wavelength, diameter, n, k):
    """Predict scattering curve for a given wavelength and diameter."""
    # Normalize the inputs the same way we did during training
    norm_wavelength = (wavelength - 450) / 100
    norm_diameter   = (diameter - 600) / 300
    norm_n = (n-1.5)/(1.86-1.5)
    norm_k = (k-0.68)/(0.32)
    
    # Convert to tensor with shape (1, 2) — one example, two features
    input_tensor = torch.FloatTensor([[norm_wavelength, norm_diameter, norm_n, norm_k]])
    
    # Run through the network
    with torch.no_grad():
        log_pred = model(input_tensor)
    
    # Convert from log space back to real brightness
    pred_curve = 10 ** log_pred.numpy().flatten()
    
    return pred_curve


def true_scattering(wavelength, diameter, n, k):
    """Compute the actual PyMieScatt scattering curve."""
    m = complex(n, k) # for any set of parameters
    theta, SL, SR, SU = ps.ScatteringFunction(
        m, wavelength, diameter,
        minAngle=0, maxAngle=180, angularResolution=1
    )
    return SU


# Pick any wavelength and diameter to test
test_wavelength = 500  # nm
test_diameter = 800   # nm
test_n = 1.6
test_k = 1.0
# Get both predictions
nn_curve = predict_scattering(test_wavelength, test_diameter, test_n, test_k)
true_curve = true_scattering(test_wavelength, test_diameter, test_n, test_k)

# Calculate error
error = np.mean((np.log10(nn_curve) - np.log10(true_curve))**2)
print(f"Mean squared error (in log space): {error:.6e}")

# Plot
plt.figure(figsize=(10, 6))
plt.plot(true_curve, '-',  color='blue', linewidth=2, label='PyMieScatt (truth)')
plt.plot(nn_curve,   '--', color='red',  linewidth=2, label='NN prediction')
plt.xlabel("Angle (degrees)")
plt.ylabel("Scattering intensity")
plt.title(f"Test: λ={test_wavelength}nm, d={test_diameter}nm")
plt.yscale('log')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# Mean squared error (in log space): 1.213315e-02

# %% [markdown]
# still understanding this part... work in progress. Doesn't look too accurate though. The neural network is able to predict values within it's trained range very well. As soon as it is given a value that is not within the trained range, it starts to perform more poorly. Values within the training range are predicted very accurately. If the neural network is asked to predict with wavelength and diameter outside of the training range, it is more inaccurate.

# %% [markdown]
# This section is used to generate some 2d plots. We'll begin by generating the logspaced diameter testing data.

# %%
N_D_SPANNING_DATA = 900
m = complex(1.6, 1.0) # match the m value the NN was trained on
fixed_lambda = 500 # I will be varying diameter not wavelength

# Log-spaced diameter sweep — wider than training range
d_span = np.logspace(np.log10(300), np.log10(1200), N_D_SPANNING_DATA)

print("Computing Brightness for Each Diamaeter with PyMieScatt")
truth = np.zeros((N_D_SPANNING_DATA, 181)) # create one dimensional array of 0s

# generate the pyMieScatt curve for each diameter value
for i, d in enumerate(d_span):
    theta, SL, SR, SU = ps.ScatteringFunction(
        m, fixed_lambda, d, minAngle=0, maxAngle=180, angularResolution=1
    )

    # add it in it's spot in the array
    truth[i] = SU
    if i % 50 == 0:
        print(f"  {i}/{N_D_SPANNING_DATA}")

# === Predictions from NN ===
print("Computing NN sweep...")
nn_pred = np.zeros((N_D_SPANNING_DATA, 181))

for i, d in enumerate(d_span):
    norm_w = (fixed_lambda - 450) / 100
    norm_d = (d - 600) / 300
    inp = torch.FloatTensor([[norm_w, norm_d, (1.6-1.5)/0.36, (1.0-0.68)/0.32]])
    with torch.no_grad():
        log_pred = model(inp)
    nn_pred[i] = 10 ** log_pred.numpy().flatten()

print(f"\nDone!")
print(f"Diameter range: {d_span[0]:.0f} to {d_span[-1]:.0f} nm")
print(f"Training was: 600 to 900 nm")
# Out:
# Computing Brightness for Each Diamaeter with PyMieScatt
#   0/900
#   50/900
#   100/900
#   150/900
#   200/900
#   250/900
#   300/900
#   350/900
#   400/900
#   450/900
#   500/900
#   550/900
#   600/900
#   650/900
#   700/900
#   750/900
#   800/900
#   850/900
# Computing NN sweep...
#
# Done!
# Diameter range: 300 to 1200 nm
# Training was: 600 to 900 nm

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Use the same color scale across both plots so they're directly comparable
vmin = np.log10(truth).min()
vmax = np.log10(truth).max()

# === PyMieScatt truth ===
im1 = axes[0].imshow(
    np.log10(truth),
    aspect='auto', origin='lower',
    extent=[0, 180, d_span[0], d_span[-1]],
    cmap='plasma', vmin=vmin, vmax=vmax
)
axes[0].set_title(f"PyMieScatt (truth) — λ={fixed_lambda}nm fixed")
axes[0].set_xlabel("Angle (degrees)")
axes[0].set_ylabel("Diameter (nm)")
# Show training range boundaries
plt.colorbar(im1, ax=axes[0], label='log10(SU)')

# === NN prediction ===
im2 = axes[1].imshow(
    np.log10(nn_pred),
    aspect='auto', origin='lower',
    extent=[0, 180, d_span[0], d_span[-1]],
    cmap='plasma', vmin=vmin, vmax=vmax
)

for ax in axes:
    ax.axhline(y=600, color='red', linestyle='--', linewidth=1)
    ax.axhline(y=900, color='red', linestyle='--', linewidth=1)
    
axes[1].set_title(f"NN prediction (n, k, d, λ) — λ={fixed_lambda}nm fixed")
axes[1].set_xlabel("Angle (degrees)")
axes[1].set_ylabel("Diameter (nm)")
plt.colorbar(im2, ax=axes[1], label='log10(SU)')

plt.tight_layout()
plt.show()

# %%
import time
import pymiediff as pmd
# Test parameters
n = 1.7
k = 0.85
wavelength = 500
diameter = 800

# Number of times to repeat each test (for averaging)
N_RUNS = 10

# Lists to store times
nn_times = []
pymiescatt_times = []
pymiediff_times = []

print(f"Running benchmark with {N_RUNS} repetitions per method...\n")

for run in range(N_RUNS):
    # --- Time NN prediction ---
    start = time.time()
    _ = predict_scattering(wavelength, diameter, n, k)
    nn_times.append(time.time() - start)
    
    # --- Time PyMieScatt ---
    start = time.time()
    m = complex(n, k)
    theta, SL, SR, SU = ps.ScatteringFunction(
        m, wavelength, diameter,
        minAngle=0, maxAngle=180, angularResolution=1
    )
    pymiescatt_times.append(time.time() - start)
    
    # --- Time pyMieDiff ---
    start = time.time()
    wl0 = torch.tensor([float(wavelength)])
    k0 = 2 * torch.pi / wl0
    p = pmd.Particle(
        r_layers=[diameter/2],
        mat_layers=[n + k*1j],
        mat_env=1.00
    )

    theta_t = torch.arange(0, 181) * torch.pi/181
    angle_scattering = p.get_angular_scattering(k0=k0, theta=theta_t)
    pymiediff_times.append(time.time() - start)
    
    print(f"Run {run+1}/{N_RUNS}: NN={nn_times[-1]*1000:.2f}ms  PyMieScatt={pymiescatt_times[-1]*1000:.2f}ms")

# Summary stats
print(f"\n--- Average times ---")
print(f"NN:         {np.mean(nn_times)*1000:.2f} ms (±{np.std(nn_times)*1000:.2f} ms)")
print(f"PyMieScatt: {np.mean(pymiescatt_times)*1000:.2f} ms (±{np.std(pymiescatt_times)*1000:.2f} ms)")
print(f"pyMieDiff:  {np.mean(pymiediff_times)*1000:.2f} ms (±{np.std(pymiediff_times)*1000:.2f} ms)")

# Plot
fig, axes = plt.subplots(figsize=(7, 5))

# Left: time series of each run
axes.plot(range(1, N_RUNS+1), [t*1000 for t in nn_times], label='NN', color='blue')
axes.plot(range(1, N_RUNS+1), [t*1000 for t in pymiescatt_times], label='PyMieScatt', color='red')
axes.plot(range(1, N_RUNS+1), [t*1000 for t in pymiediff_times], label='pyMieDiff', color='green')
axes.set_xlabel('Run number')
axes.set_ylabel('Time (ms)')
axes.set_title('Per-run computation times')
axes.set_yscale('log')
axes.legend()
axes.grid(True, alpha=0.3)

plt.show()
# Out:
# Running benchmark with 10 repetitions per method...
#
# Run 1/10: NN=0.66ms  PyMieScatt=20.62ms
# Run 2/10: NN=0.37ms  PyMieScatt=17.11ms
# Run 3/10: NN=0.25ms  PyMieScatt=20.21ms
# Run 4/10: NN=0.22ms  PyMieScatt=20.99ms
# Run 5/10: NN=0.22ms  PyMieScatt=17.83ms
# Run 6/10: NN=0.22ms  PyMieScatt=21.52ms
# Run 7/10: NN=0.21ms  PyMieScatt=19.30ms
# Run 8/10: NN=0.17ms  PyMieScatt=19.02ms
# Run 9/10: NN=0.23ms  PyMieScatt=17.56ms
# Run 10/10: NN=0.18ms  PyMieScatt=17.50ms
#
# --- Average times ---
# NN:         0.27 ms (±0.14 ms)
# PyMieScatt: 19.17 ms (±1.53 ms)
# pyMieDiff:  8.15 ms (±1.15 ms)

# %%
test_mse = ((model(x_test) - y_test) ** 2).mean().item()
print(f"Final MSE on test set: {test_mse:.8f}")
# Out:
# Final MSE on test set: 0.01856173

# %%
with torch.no_grad():
    test_pred = model(x_test)

n_test_particles = x_test.shape[0]
print(f"Predicted log scattering shape: {test_pred.shape}")
print(f"Number of test particles: {n_test_particles}")

particle_indices = np.random.choice(n_test_particles, 4, replace=False)
colours = ['blue', 'orange', 'green', 'red']
plt.figure(figsize=(11, 7))

angles = np.arange(181)  # 0…180 degrees

for idx, color in zip(particle_indices, colours):
    true_curve = 10 ** y_test[idx].numpy()
    pred_curve = 10 ** test_pred[idx].numpy()

    # Un-normalize using the SAME formulas as Cell 6, in the SAME column order
    wavelength = x_test[idx, 0].item() * 100   + 450
    diameter   = x_test[idx, 1].item() * 300   + 600
    n          = x_test[idx, 2].item() * 0.36  + 1.5
    k          = x_test[idx, 3].item() * 0.32  + 0.68

    label = f"λ={wavelength:.0f}nm, d={diameter:.0f}nm, n={n:.2f}, k={k:.2f}"
    plt.plot(angles, true_curve, '-',  color=color, label=f"True  {label}")
    plt.plot(angles, pred_curve, '--', color=color, label=f"Pred  {label}")

plt.xlabel("Angle (degrees)")
plt.ylabel("Scattering intensity (SU)")
plt.title("Mie scattering curves: True vs Predicted (4 random test particles)")
plt.yscale('log')
plt.legend(fontsize=8)
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# Predicted log scattering shape: torch.Size([200, 181])
# Number of test particles: 200

# %%
# Fixed conditions — vary only diameter
test_wavelength = 500
test_n = 1.6
test_k = 1.0

# Training range for diameter was 600–900 nm.
# 500/550 are below the range, 950/1000 are above.
diameters = [500, 550, 950, 1000]
colors    = ['red', 'green', 'blue', 'orange']

# Truth curves (PyMieScatt)
true_curves = [true_scattering(test_wavelength, d, test_n, test_k) for d in diameters]

# NN predictions
nn_curves = [predict_scattering(test_wavelength, d, test_n, test_k) for d in diameters]

angles = np.arange(181)  # 0…180 degrees

plt.figure(figsize=(10, 6))

for d, color, true_curve, nn_curve in zip(diameters, colors, true_curves, nn_curves):
    plt.plot(angles, true_curve, '-',  color=color, label=f'True d={d}nm')
    plt.plot(angles, nn_curve,   '--', color=color, label=f'NN   d={d}nm')

plt.xlabel("Angle (degrees)")
plt.ylabel("Scattering intensity (SU)")
plt.title(f"NN vs PyMieScatt outside training range (n={test_n}, k={test_k}, λ={test_wavelength}nm)")
plt.yscale('log')
plt.legend(fontsize=9, ncol=2)
plt.grid(True, alpha=0.3)
plt.show()

# %%
print(x_train.shape)
# Out:
# torch.Size([800, 4])
